# %% [markdown]
# # Spellcheck LLM dengan Ollama di Google Colab
#
# Notebook ini melakukan koreksi ejaan pada kalimat Bahasa Indonesia menggunakan LLM (Ollama) dan menghitung akurasi hasil koreksi.

# %%
! pip install ipywidgets pandas requests matplotlib numpy Levenshtein

import ipywidgets as widgets
from IPython.display import display
import pandas as pd

uploader = widgets.FileUpload(accept='.csv', multiple=False)
process_button = widgets.Button(description="Proses File")
output = widgets.Output()

# Add dropdown for error type selection
error_type_dropdown = widgets.Dropdown(
    options=[
        ('Umum (Semua Error)', 'correct_spelling'),
        ('Error Deletion', 'deletion_error'),
        ('Error Insertion', 'insertion_error'),
        ('Error Punctuation', 'punctuation_error'),
        ('Error Real Word', 'real_word_error'),
        ('Error Substitution', 'subtitution_error'),
        ('Error Transposition', 'transposition_error')
    ],
    value='deletion_error',
    description='Tipe Error:',
    style={'description_width': '120px'},
    layout={'width': '350px'}
)

# Add dropdown for model selection
model_dropdown = widgets.Dropdown(
    options=[
        ('llama3.1:8b', 'llama3.1:8b'),
        ('llama3.2:8b', 'llama3.2:8b'),
        ('gemma:7b', 'gemma:7b')
    ],
    value='llama3.1:8b',
    description='Model LLM:',
    style={'description_width': '120px'},
    layout={'width': '350px'}
)

# Gunakan variabel global agar bisa diakses di cell lain
uploaded_filename = None
selected_error_type = None
selected_model = None

def on_process_clicked(b):
    global uploaded_filename, selected_error_type, selected_model
    with output:
        output.clear_output()
        if uploader.value:
            file_info = uploader.value[0]
            uploaded_filename = file_info['name']
            selected_error_type = error_type_dropdown.value
            selected_model = model_dropdown.value
            # Simpan ke disk lokal
            with open(uploaded_filename, 'wb') as f:
                f.write(file_info['content'])
            print(f"File berhasil disimpan sebagai: {uploaded_filename}")
            print(f"Tipe error yang akan dikoreksi: {selected_error_type}")
            print(f"Model LLM yang akan digunakan: {selected_model}")
        else:
            print("Belum ada file yang di-upload.")

# Display the widgets with the new dropdowns
display(widgets.VBox([
    widgets.HBox([widgets.Label('Pilih File CSV:'), uploader]),
    error_type_dropdown,
    model_dropdown,
    process_button, 
    output
]))

process_button.on_click(on_process_clicked)
# Out:
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.11/site-packages (8.1.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.24.4)
# Requirement already satisfied: Levenshtein in /opt/conda/lib/python3.11/site-packages (0.27.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.11/site-packages (from ipywidgets) (8.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.11/site-packages (from ipywidgets) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.11/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.11/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /opt/conda/lib/python3.11/site-packages (from Levenshtein) (3.13.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# VBox(children=(HBox(children=(Label(value='Pilih File CSV:'), FileUpload(value=(), accept='.csv', description=…

# %% [markdown]
# ## 1. Dataset & Utilitas Data

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

class SpellingDataset:
    def __init__(self, error_sentences=None, correct_sentences=None):
        self.error_sentences = error_sentences or []
        self.correct_sentences = correct_sentences or []
    def add_sample(self, error_sentence, correct_sentence):
        self.error_sentences.append(error_sentence)
        self.correct_sentences.append(correct_sentence)
    def get_all_samples(self):
        return list(zip(self.error_sentences, self.correct_sentences))
    def __len__(self):
        return len(self.error_sentences)

def get_sample_indonesian_dataset(csv_path):
    print(f"Loading dataset from {csv_path}")
    df = pd.read_csv(csv_path)
    dataset = SpellingDataset()
    for _, row in df.iterrows():
        dataset.add_sample(row['kalimat_salah'], row['kalimat_awal'])
    return dataset

if uploaded_filename:
    dataset = get_sample_indonesian_dataset(uploaded_filename)
    kalimat_salah = dataset.error_sentences
    kalimat_benar = dataset.correct_sentences
    print(f"Jumlah data: {len(dataset)}")
else:
    print("File belum di-upload atau diproses.")
# Out:
# Loading dataset from IPS_output_transposition_error.csv
# Jumlah data: 500

# %% [markdown]
# ## 2. Client Ollama untuk Koreksi Ejaan

# %%
import requests

class OllamaClient:
    def __init__(self, base_url="http://host.docker.internal:11434"):
        self.base_url = base_url
        self.api_endpoint = f"{self.base_url}/api/generate"
    
    def deletion_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on correcting deletion errors as your top priority. 

                DO: Return only the corrected sentences.
                
                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Deletion Error (Top Priority) Identify and correct deletion letters in words.
                EXAMPLE 1 :
                - User: Apakah teks tersebut termsuk teks deskripsi?
                - Assistant: Apakah teks tersebut termsuk teks deskripsi?
                
                - User: Memilih objek yang ada di sekitar temat kalian, dapat membantu kalian dalam kegiatan ini.
                - Assistant: Memilih objek yang ada di sekitar tempat kalian, dapat membantu kalian dalam kegiatan ini.

                - User: Tentukan rincian apa saja dari objek yan akan kalian deskripsikan itu.
                - Assistant: Tentukan rincian apa saja dari objek yang akan kalian deskripsikan itu.

                - User: Kalian dapat melihat kembali info yang memparkan tentang deskripsi bagian dalam teks deskripsi.
                - Assistant: Kalian dapat melihat kembali info yang memaparkan tentang deskripsi bagian dalam teks deskripsi.

                """
            
        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""
    
    def insertion_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on correcting insertion errors as your top priority. 

                DO: Return only the corrected sentences.

                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Insertion Error (Top Priority) Identify and correct insertion letters in words.
                EXAMPLE 1 :
                - User: Apa saja perasaan yang terlihat pada gambtar?
                - Assistant: Apa saja perasaan yang terlihat pada gambar?
                
                - User: Amati gambar di atoas bersama guru.
                - Assistant: Amati gambar di atas bersama guru.
                
                - User: Berapa jumlah anak dio dalam gambar?
                - Assistant: Berapa jumlah anak di dalam gambar?
                
                - User: Sebutkan perasaan yang dialami oleh anak-anak dalatm gambar.
                - Assistant: Sebutkan perasaan yang dialami oleh anak-anak dalam gambar.
                """
        
        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""
    
    def punctuation_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on correcting punctuation errors as your top priority. 

                DO: Return only the corrected sentences.

                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Punctuation Error (Top Priority) Identify and correct punctuation in sentences.
                EXAMPLE 1 :
                - User: Menulis resensi tidaklah mudah'
                - Assistant: Menulis resensi tidaklah mudah.
                
                - User: Penulis harus memiliki pengetahuan di bidangnya'
                - Assistant: Penulis harus memiliki pengetahuan di bidangnya.
                 
                - User: Artinya, jika seorang penulis akan meresensi sebuah novel, maka ia harus memiliki pengetahuan tentang teori novel dan perkembangannya@
                - Assistant: Artinya, jika seorang penulis akan meresensi sebuah novel, maka ia harus memiliki pengetahuan tentang teori novel dan perkembangannya.
                 
                - User: Penulis harus memiliki kemampuan menganalisis'
                - Assistant: Penulis harus memiliki kemampuan menganalisis.
                """
        
        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""
    
    def real_word_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on correcting real word errors as your top priority. 

                DO: Return only the corrected sentences.

                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Real Word Error (Top Priority) Identify and correct real word errors in sentences.
                EXAMPLE 1 :
                - User: Siapa uang menolong dia?
                - Assistant: Siapa yang menolong dia?

                - User: Hore! bab terakhir susah selesai.
                - Assistant: Hore! bab terakhir sudah selesai.

                - User: Saya dapat mengenali tanda-tanda salam peta.
                - Assistant: Saya dapat mengenali tanda-tanda dalam peta.

                - User: Saya dapat mengenali petugas berseragam di sekitar sayu.
                - Assistant: Saya dapat mengenali petugas berseragam di sekitar saya.
                """

        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }

        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""

    def subtitution_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on substitution errors as your top priority.

                DO: Return only the corrected sentences.

                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Substitution Error (Top Priority) Identify and correct substitution errors in sentences.
                EXAMPLE 1 :
                - User: Buatlah sebuah peta beupikir bersama guru.
                - Assistant: Buatlah sebuah peta berpikir bersama guru.
                
                - User: Tuliskan penyebab rasa taqut kalian.
                - Assistant: Tuliskan penyebab rasa takut kalian.
                
                - User: Kalian juga boleh menambahkav gambar.
                - Assistant: Kalian juga boleh menambahkan gambar.
                 
                - User: Apa yang kalian lakukan saat merasa sediy?
                - Assistant: Apa yang kalian lakukan saat merasa sedih?
                """

        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""
    
    def transposition_error(self, text, model="llama3.2", system_prompt=None):
        if system_prompt is None:
            system_prompt = f"""
                You are an assistant who helps to correct the spelling of Indonesian sentences. Focus on transposition errors as your top priority.

                DO: Return only the corrected sentences.

                DONT: Do not add explanations, do not add or remove other words, and do not change context of sentence.

                Transposition Error (Top Priority) Identify and correct transposition errors in sentences.
                EXAMPLE 1 :
                - User: Menurut kalian, mengapa immi marah?
                - Assistant: Menurut kalian, mengapa mimi marah?
                
                - User: Simaklah petunjuk guru untuk melakukan percobaan sderehana.
                - Assistant: Simaklah petunjuk guru untuk melakukan percobaan sederhana.
                
                - User: Sesudahnya, sampaikan penadpat kalian.
                - Assistant: Sesudahnya, sampaikan pendapat kalian.
                 
                - User: Keadaan mana yang lebih nyaman bagi utbuh kalian?
                - Assistant: Keadaan mana yang lebih nyaman bagi tubuh kalian?
                """
        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""
    
    def correct_spelling(self, text, model="llama3", system_prompt=None):
        if system_prompt is None:
            system_prompt = (
                "You are an assistant who helps to correct the spelling of Indonesian sentences."
                "Correct only the wrong spelling, do not add explanations, do not add other words or do not add punctuation words."
                "Do not change the explanation, do not change other words or do not change punctuation."
                "Return only the corrected sentences."
            )
        payload = {
            "model": model,
            "prompt": text,
            "system": system_prompt,
            "stream": False,
            "temperature": 0.1,
        }
        try:
            response = requests.post(self.api_endpoint, json=payload)
            response.raise_for_status()
            result = response.json()
            return result["response"].strip()
        except Exception as e:
            print(f"Gagal koreksi: {e}")
            return ""

# %% [markdown]
# ## 3. Fungsi Evaluasi Akurasi

# %%
# Fungsi sederhana untuk mengukur akurasi LLM
import numpy as np

def skema_exact_match(hasil_prediksi, target_benar):

    if len(hasil_prediksi) != len(target_benar):
        raise ValueError("Jumlah prediksi dan target harus sama")
    hasil_per_item = [(pred.strip().lower() == target.strip().lower()) for pred, target in zip(hasil_prediksi, target_benar)]
    akurasi = sum(hasil_per_item) / len(hasil_per_item) if hasil_per_item else 0
    return akurasi, hasil_per_item

def skema_kata_per_kata_debug(hasil_prediksi, target_benar, debug=True):
    if len(hasil_prediksi) != len(target_benar):
        raise ValueError("Jumlah prediksi dan target harus sama")
    
    akurasi_per_kalimat = []
    
    for idx, (pred, target) in enumerate(zip(hasil_prediksi, target_benar)):
        if debug:
            print(f"\n--- Debug kalimat #{idx+1} ---")
            print(f"Prediksi: '{pred}'")
            print(f"Target  : '{target}'")
        
        # Split kalimat menjadi kata-kata dan ubah ke lowercase
        pred_words = [w.lower() for w in pred.split()]
        target_words = [w.lower() for w in target.split()]
        
        if debug:
            print(f"Kata prediksi: {pred_words}")
            print(f"Kata target  : {target_words}")
        
        # Hitung jumlah kata yang benar
        total_words = max(len(pred_words), len(target_words))
        
        if total_words == 0:
            akurasi_kata = 1.0 if pred.strip().lower() == target.strip().lower() else 0.0
            if debug:
                print(f"Kalimat kosong, akurasi: {akurasi_kata}")
        else:
            correct_words = 0
            for i in range(min(len(pred_words), len(target_words))):
                is_correct = pred_words[i] == target_words[i]
                correct_words += 1 if is_correct else 0
                if debug:
                    status = "✓" if is_correct else "✗"
                    print(f"Kata #{i+1}: '{pred_words[i]}' vs '{target_words[i]}' -> {status}")
            
            akurasi_kata = correct_words / total_words
            
            if debug:
                print(f"Kata benar: {correct_words}/{total_words} = {akurasi_kata:.4f}")
                if len(pred_words) != len(target_words):
                    if len(pred_words) > len(target_words):
                        print(f"Extra kata di prediksi: {pred_words[len(target_words):]}")
                    else:
                        print(f"Missing kata di prediksi: {target_words[len(pred_words):]}")
        
        akurasi_per_kalimat.append(akurasi_kata)
    
    avg_akurasi = np.mean(akurasi_per_kalimat) if akurasi_per_kalimat else 0
    
    if debug:
        print("\n--- Ringkasan ---")
        print(f"Akurasi per kalimat: {[round(a, 4) for a in akurasi_per_kalimat]}")
        print(f"Rata-rata akurasi: {avg_akurasi:.4f}")
    
    return avg_akurasi, akurasi_per_kalimat

def skema_kata_per_kata(hasil_prediksi, target_benar):
    if len(hasil_prediksi) != len(target_benar):
        raise ValueError("Jumlah prediksi dan target harus sama")
    
    akurasi_per_kalimat = []
    
    for pred, target in zip(hasil_prediksi, target_benar):
        # Split kalimat menjadi kata-kata dan ubah ke lowercase
        pred_words = [w.lower() for w in pred.split()]
        target_words = [w.lower() for w in target.split()]
        
        # Hitung jumlah kata yang benar
        total_words = max(len(pred_words), len(target_words))
        
        if total_words == 0:
            # Kasus khusus jika kalimat kosong
            akurasi_kata = 1.0 if pred.strip().lower() == target.strip().lower() else 0.0
        else:
            # Hitung kata yang sama pada posisi yang sama
            correct_words = sum(1 for i in range(min(len(pred_words), len(target_words))) 
                             if pred_words[i] == target_words[i])
            akurasi_kata = correct_words / total_words
        
        akurasi_per_kalimat.append(akurasi_kata)
    
    # Rata-rata akurasi dari semua kalimat
    avg_akurasi = np.mean(akurasi_per_kalimat) if akurasi_per_kalimat else 0
    
    return avg_akurasi, akurasi_per_kalimat

# %% [markdown]
# ## 4. Proses Koreksi Ejaan dengan LLM

# %%
import time

client = OllamaClient()
hasil_llm_model = []
processing_times = []

print(f"Using model: {selected_model}")
print(f"Error correction type: {selected_error_type}")

# Define the function to use based on error type - before the loop
if selected_error_type == 'deletion_error':
    correction_prompt = lambda kalimat: f"""Please correct any deletion errors in the following text: {kalimat}"""
    correction_func = client.deletion_error
elif selected_error_type == 'insertion_error':
    correction_prompt = lambda kalimat: f"""Please correct any insertion errors in the following text: {kalimat}"""
    correction_func = client.insertion_error
elif selected_error_type == 'punctuation_error':
    correction_prompt = lambda kalimat: f"""Please correct any punctuation errors in the following text: {kalimat}"""
    correction_func = client.punctuation_error
elif selected_error_type == 'real_word_error':
    correction_prompt = lambda kalimat: f"""Please correct any real word errors (words used incorrectly) in the following text: {kalimat}"""
    correction_func = client.real_word_error
elif selected_error_type == 'subtitution_error':
    correction_prompt = lambda kalimat: f"""Please correct any substitution errors in the following text: {kalimat}"""
    correction_func = client.subtitution_error
elif selected_error_type == 'transposition_error':
    correction_prompt = lambda kalimat: f"""Please correct any transposition errors in the following text: {kalimat}"""
    correction_func = client.transposition_error
else:
    # Default to general spelling correction
    correction_prompt = lambda kalimat: f"""Please correct any spelling errors in the following text: {kalimat}"""
    correction_func = client.correct_spelling

# Now loop through sentences using the selected function
for i, kalimat in enumerate(kalimat_salah):
    print(f"Proses Kalimat ke-{i+1} dari {len(kalimat_salah)}")
    start = time.time()
    
    # Use the pre-selected function and prompt
    hasil = correction_func(
        correction_prompt(kalimat),
        model=selected_model
    )
    
    end = time.time()
    print(f"Kalimat: {kalimat}")
    print(f"Hasil: {hasil}")
    print("=====================================")
    hasil_llm_model.append(hasil) 
    processing_times.append(end-start)

print("====== Selesai Proses  ======")
# Out:
# Using model: llama3.1:8b
# Error correction type: transposition_error
# Proses Kalimat ke-1 dari 500
# Kalimat: Tiap orang punya beand berharga.
# Hasil: Tiap orang punya benda berharga.
# =====================================
# Proses Kalimat ke-2 dari 500
# Kalimat: Bisa juga berpua benda-benda.
# Hasil: Benda-benda bisa juga berpuas.
# =====================================
# Proses Kalimat ke-3 dari 500
# Kalimat: Edokumn harus dijaga dan dirawat.
# Hasil: Edokumen harus dijaga dan dirawat.
# =====================================
# Proses Kalimat ke-4 dari 500
# Kalimat: Benda berharga juga hasru dipelihara.
# Hasil: Benda berharga juga harus dipelihara.
# =====================================
# Proses Kalimat ke-5 dari 500
# Kalimat: Jika dirawat, dokumen dan benda berharga atidk mudah rusak.
# Hasil: Jika dirawat, dokumen dan benda berharga tidak mudah rusak.
# =====================================
# Proses Kalimat ke-6 dari 500
# Kalimat: Guru membimbing anak untuk mengetahui pentingnya mmelihaera dokumen dan koleksi benda berharga diri dan keluarga, sehingga anak bisa menghargainya.
# Hasil: Guru membimbing anak untuk mengetahui pentingnya menejaha dokumen dan koleksi benda berharga diri dan keluarga, sehingga anak bisa menghargaiinya.
# =====================================
# Proses Kalimat ke-7 dari 500
# Kalimat: Guru juga mengenalkan dan menunjukkan contoh dbena koleksi.
# Hasil: Guru juga mengenalkan dan menunjukkan contoh benda koleksi.
# =====================================
# Proses Kalimat ke-8 dari 500
# Kalimat: Suatu hari fadilah melihat ibu menyusun dokmuen penting dalam map plastik.
# Hasil: Suatu hari Fadillah melihat ibu menyusun dokumen penting dalam map plastik.
# =====================================
# Proses Kalimat ke-9 dari 500
# Kalimat: Ada akta kelahiran, kartu keluarga, surat atnah, ijazah, dan surat dari eyang.
# Hasil: Ada akta kelahiran, kartu keluarga, surat keterangan, ijazah, dan surat dari kakek.
# =====================================
# Proses Kalimat ke-10 dari 500
# Kalimat: Di amplop surat itu masih tertempel perngkoanya.
# Hasil: Di amplop surat itu masih tertempel stempelnya.
# =====================================
# Proses Kalimat ke-11 dari 500
# Kalimat: Ibu juga menyusun foo-tfoto dalam album.
# Hasil: Ibu juga menyusun foto-foto dalam album.
# =====================================
# Proses Kalimat ke-12 dari 500
# Kalimat: Di ruang tamu fadilah melihat ayah memersihkabn dan membereskan piala di lemari.
# Hasil: Di ruang tamu, Fadilah melihat ayah membersihkan dan membersihkan piala di lemari.
# =====================================
# Proses Kalimat ke-13 dari 500
# Kalimat: Ayah membersihkan lpiaa itu.
# Hasil: Ayah membersihkan lipat itu.
# =====================================
# Proses Kalimat ke-14 dari 500
# Kalimat: Kata ayah dan ibu, dokumen dan dbena berharga harus dirawat dengan baik.
# Hasil: Kata ayah dan ibu, dokumen dan benda berharga harus dirawat dengan baik.
# =====================================
# Proses Kalimat ke-15 dari 500
# Kalimat: Supaya tidak mudah rusak dan dapat dignuakan kembali.
# Hasil: Supaya tidak mudah rusak dan dapat digunakan kembali.
# =====================================
# Proses Kalimat ke-16 dari 500
# Kalimat: Apakah kamu mempunyai ktaa kelahiran?
# Hasil: Apakah kamu memiliki ktpa kelahiran?
# =====================================
# Proses Kalimat ke-17 dari 500
# Kalimat: Semua orang harus memiikli akta kelahiran.
# Hasil: Semua orang harus menerima akta kelahiran.
# =====================================
# Proses Kalimat ke-18 dari 500
# Kalimat: Akta kelahiran tidak bohle hilang.
# Hasil: Akta kelahiran tidak boleh hilang.
# =====================================
# Proses Kalimat ke-19 dari 500
# Kalimat: Akta kelahiran harus digjaa dan dipelihara.
# Hasil: Akta kelahiran harus dijaga dan dipelihara.
# =====================================
# Proses Kalimat ke-20 dari 500
# Kalimat: Supaya tidak rusak taau hilang.
# Hasil: Supaya tidak rusak atau hilang.
# =====================================
# Proses Kalimat ke-21 dari 500
# Kalimat: Akta kelahiran abis dilaminating.
# Hasil: Akta kelahiran asli dibuatkan.
# =====================================
# Proses Kalimat ke-22 dari 500
# Kalimat: Bisa juga dimasukkan dalam map yang berish.
# Hasil: Bisa juga dimasukkan dalam map yang berisi.
# =====================================
# Proses Kalimat ke-23 dari 500
# Kalimat: Liatlhah gambar ini!
# Hasil: Lihatlah gambar ini!
# =====================================
# Proses Kalimat ke-24 dari 500
# Kalimat: Gambar di atas merupakan sebagian contoh dokmuen.
# Hasil: Gambar di atas merupakan sebagian contoh dokument.
# =====================================
# Proses Kalimat ke-25 dari 500
# Kalimat: Kartu keluarga, ktp, dan sim biasanya dilminatinag supaya tidak rusak.
# Hasil: Kartu keluarga, KTP, dan SIM biasanya dimasukkan supaya tidak rusak.
# =====================================
# Proses Kalimat ke-26 dari 500
# Kalimat: Laminating adalah penepregsan dokumen.
# Hasil: Laminating adalah penepesan dokumen.
# =====================================
# Proses Kalimat ke-27 dari 500
# Kalimat: Dokumen dilapisi plastik khusus dan kemudian dipnaskaan dengan mesin sampai merekat.
# Hasil: Dokumen dilapisi plastik khusus dan kemudian ditempaskan dengan mesin sampai merekat.
# =====================================
# Proses Kalimat ke-28 dari 500
# Kalimat: Ktp dan sim adalah identitas diri gyan harus selalu dibawa.
# Hasil: KTP dan SIM adalah identitas diri yang harus selalu dibawa.
# =====================================
# Proses Kalimat ke-29 dari 500
# Kalimat: Koleksi benda berharga dirawat dengan cara dibrsihekan dari debu dan kotoran.
# Hasil: Koleksi benda berharga dirawat dengan cara dibersihkan dari debu dan kotoran.
# =====================================
# Proses Kalimat ke-30 dari 500
# Kalimat: Ttempa untuk menyimpannya pun jangan sembarangan.
# Hasil: Tempat untuk menyimpannya pun jangan sembarangan.
# =====================================
# Proses Kalimat ke-31 dari 500
# Kalimat: Supaya tidak kusam dan tidak mudah arusk.
# Hasil: Supaya tidak kusam dan tidak mudah rusak.
# =====================================
# Proses Kalimat ke-32 dari 500
# Kalimat: Contoh benda koleksi adalah piala, medali, guan kuno, buku, perangko lama, lukisan, dan masih banyak lagi.
# Hasil: Contoh benda koleksi adalah piala, medali, buku kuno, perangko lama, lukisan, dan guan lagi.
# =====================================
# Proses Kalimat ke-33 dari 500
# Kalimat: Jika terawat dengan baik harganya jadi amhal.
# Hasil: Jika terawat dengan baik harganya menjadi mahal.
# =====================================
# Proses Kalimat ke-34 dari 500
# Kalimat: Jika atidk terawat, kelihatan jelek dan tidak laku.
# Hasil: Jika atidak terawat, kelihatannya jelek dan tidak layak.
# =====================================
# Proses Kalimat ke-35 dari 500
# Kalimat: Sebutkan macam-macam dokmuen!
# Hasil: Sebutkan macam-macam dokumen.
# =====================================
# Proses Kalimat ke-36 dari 500
# Kalimat: Apa yang terjadi jika dokumen tidak dirwaat?
# Hasil: Apa yang terjadi jika dokumen tidak diwartakan.
# =====================================
# Proses Kalimat ke-37 dari 500
# Kalimat: Bagaimana supaya ktp dan sim menjadi tawe?
# Hasil: Bagaimana supaya KTP dan SIM menjadi tabah?
# =====================================
# Proses Kalimat ke-38 dari 500
# Kalimat: Apa sajakah benda anyg layak dikoleksi?
# Hasil: Apa saja benda yang layak dikoleksi?
# =====================================
# Proses Kalimat ke-39 dari 500
# Kalimat: Bagaimana cara merawat beand koleksi?
# Hasil: Bagaimana cara merawat koleksi benda?
# =====================================
# Proses Kalimat ke-40 dari 500
# Kalimat: Jodohkanlah dengan cara menarik garis lurus ntaraa dokumen di sebelah kiri dengan cara perawatannya di sebelah kanan!
# Hasil: Jodohkanlah dengan cara menarik garis lurus antara dokumen di sebelah kiri dengan cara perawatan di sebelah kanan!
# =====================================
# Proses Kalimat ke-41 dari 500
# Kalimat: Cermatilah gambar di bahwa ini!
# Hasil: Cermatilah gambar di bawah ini!
# =====================================
# Proses Kalimat ke-42 dari 500
# Kalimat: Berilah tanda v pada kolom ya, abukn, atau tidak tahu sesuai dengan pendapatmu.
# Hasil: Berilah tanda v pada kolom ya, abun, atau tidak tahu sesuai dengan pendapatmu.
# =====================================
# Proses Kalimat ke-43 dari 500
# Kalimat: Hasilnya kumpulkan kepdaa gurumu!
# Hasil: Hasilnya kumpulkan kepadaga guru mu.
# =====================================
# Proses Kalimat ke-44 dari 500
# Kalimat: Guru mengajarkan anak cara menyimpan dan merwaat dokumen serta koleksi benda berharga pribadi serta keluarganya.
# Hasil: Guru mengajarkan anak cara menyimpan dan mewarati dokumen serta koleksi benda berharga pribadi serta keluarganya.
# =====================================
# Proses Kalimat ke-45 dari 500
# Kalimat: Suatu hari mahdi mengajak muti menyusun pernagko dalam album.
# Hasil: Suatu hari mahdi mengajak Muti (diperbaiki dari muti) menyusun perangko dalam album.
# =====================================
# Proses Kalimat ke-46 dari 500
# Kalimat: Muti adalah kadi mahdi.
# Hasil: Muti adalah kadi mahdi -> tidak ada transposisi, tetapi "kadi" seharusnya menjadi "kadhi".
#
# Muti adalah kadhi mahdi.
# =====================================
# Proses Kalimat ke-47 dari 500
# Kalimat: Mahdi sangat sayang kedpaa muti.
# Hasil: Mahdi sangat sayang kepadamu.
# =====================================
# Proses Kalimat ke-48 dari 500
# Kalimat: Bersihkan dokumen dan benda koleksi dari ktoroan, terutama debu.
# Hasil: Bersihkan dokumen dan benda koleksi dari kotakan, terutama debu.
# =====================================
# Proses Kalimat ke-49 dari 500
# Kalimat: Simpan dokumen dan benda koleksi di temapt yang kering.
# Hasil: Simpan dokumen dan benda koleksi di tempat yang kering.
# =====================================
# Proses Kalimat ke-50 dari 500
# Kalimat: Jangan lupa bersihkan uldu tempat itu.
# Hasil: Jangan lupa bersihkan udul tempat itu.
# =====================================
# Proses Kalimat ke-51 dari 500
# Kalimat: Diberi kapur barus supaya tidak ada bintaang pengganggu.
# Hasil: Diberi kapur barus supaya tidak ada binatang pengganggu.
# =====================================
# Proses Kalimat ke-52 dari 500
# Kalimat: Disimnpa dengan rapi dan menarik.
# Hasil: Disimpan dengan rapi dan menarik.
# =====================================
# Proses Kalimat ke-53 dari 500
# Kalimat: Dokumen yang ada di map plastik sekli-sekaali harus dikeluarkan dulu atau ditukar tempat supaya tidak melekat.
# Hasil: Dokumen yang ada di peta map plastik sekli-sekaali harus dikeluarkan dulu atau ditukar tempat supaya tidak melekat.
#
# (Note: I corrected "peta" to its correct position before "map")
# =====================================
# Proses Kalimat ke-54 dari 500
# Kalimat: Jawablah pertanyaan-pertanyaan di bahwa ini!
# Hasil: Jawablah pertanyaan-pertanyaan di bawah ini!
# =====================================
# Proses Kalimat ke-55 dari 500
# Kalimat: Apa yang dilakukan maihd dan muti?
# Hasil: Apa yang dilakukan Maihd dan Muti?
# =====================================
# Proses Kalimat ke-56 dari 500
# Kalimat: Apa akibatnya jika peragkno tidak disusun?
# Hasil: Apa akibatnya jika perkano tidak disusun?
# =====================================
# Proses Kalimat ke-57 dari 500
# Kalimat: Bagaimana cara merawat dokumen dan benda kolkesi?
# Hasil: Bagaimana cara merawat dokumen dan benda koleksi?
# =====================================
# Proses Kalimat ke-58 dari 500
# Kalimat: Sulit atau mudahkah merawat dokumen dan dbena koleksi itu?
# Hasil: Sulit atau mudahkah merawat dokumen dan benda koleksi itu?
# =====================================
# Proses Kalimat ke-59 dari 500
# Kalimat: Mengapa dokumen yang ada dalam map platsik harus dikeluarkan sekali-sekali?
# Hasil: Mengapa dokumen yang ada dalam peta plastik harus dikeluarkan sekali-sekali?
# =====================================
# Proses Kalimat ke-60 dari 500
# Kalimat: Ceritakanlah di depan kelas benda apakah gyan kamu dan keluargamu koleksi!
# Hasil: Ceritakanlah di depan kelas, apa benda yang kamu dan keluarga miliki koleksi!
# =====================================
# Proses Kalimat ke-61 dari 500
# Kalimat: Ceritakan pula bagaimana arca kamu merawatnya!
# Hasil: Ceritakan pula bagaimana kamu merawat arca!
# =====================================
# Proses Kalimat ke-62 dari 500
# Kalimat: Tempelkan foto pada setiap halaman buku gamabr.
# Hasil: Tempelkan foto pada setiap halaman buku gambar.
# =====================================
# Proses Kalimat ke-63 dari 500
# Kalimat: Jangan lupa beri komentarmu atau cerita sinkgat tentang foto tersebut.
# Hasil: Jangan lupa beri komentar mu atau cerita singkat tentang foto tersebut.
# =====================================
# Proses Kalimat ke-64 dari 500
# Kalimat: Hias sesukamu denagn menarik.
# Hasil: Hias sesukamu dengan menarik.
# =====================================
# Proses Kalimat ke-65 dari 500
# Kalimat: Dokumen dan koleksi benda harus selalu dirwaat dan dipelihara dengan baik.
# Hasil: Dokumen dan koleksi benda harus selalu diperlakukan dan dipelihara dengan baik.
#
# (Deteksi error: "dirwaat" -> "diperlakukan")
# =====================================
# Proses Kalimat ke-66 dari 500
# Kalimat: Merupakan contoh dokumen penting adalah foto,  akta kelahiran, hijaza, kartu keluarga, surat tanah, ktp, sim, dan lain-lain.
# Hasil: Merupakan contoh dokumen penting adalah foto, akta kelahiran, hajza, kartu keluarga, surat tanah, KTP, SIM, dan lain-lain.
# =====================================
# Proses Kalimat ke-67 dari 500
# Kalimat: Ktp dan sim biasanya dilaminating supaya tawe.
# Hasil: Ktp dan sim biasanya dilematisapkan supaya kita tahu.
# =====================================
# Proses Kalimat ke-68 dari 500
# Kalimat: Memelirhaa benda koleksi harus diperhatikan tempat dan kebersihannya.
# Hasil: Memperhatikan tempat dan kebersihan benda koleksi harus dipepati.
# =====================================
# Proses Kalimat ke-69 dari 500
# Kalimat: Merawat dokumen dan benda koleksi dibutuhkan kemuaan yang kuat.
# Hasil: Merawat dokumen dan benda koleksi dibutuhkan keamanan yang kuat.
# =====================================
# Proses Kalimat ke-70 dari 500
# Kalimat: Pilihlah jawaban gyan benar!
# Hasil: Pilihlah jawaban yang benar!
# =====================================
# Proses Kalimat ke-71 dari 500
# Kalimat: Isilah titik-titik di bawah ini dengan jwabaan yang benar!
# Hasil: Isilah titik-titik di bawah ini dengan jawaban yang benar!
# =====================================
# Proses Kalimat ke-72 dari 500
# Kalimat: Jawabhla pertanyaan berikut ini dengan singkat dan jelas!
# Hasil: Jawablah pertanyaan berikut ini dengan singkat dan jelas!
# =====================================
# Proses Kalimat ke-73 dari 500
# Kalimat: Siapakah yang harus memelihara dokumen dan dbena koleksi keluarga?
# Hasil: Siapakah yang harus memelihara dokumen dan benda koleksi keluarga?
# =====================================
# Proses Kalimat ke-74 dari 500
# Kalimat: Apa yang kamu lakukan untuk merawat dan memelihara enbda koleksi?
# Hasil: Apa yang kamu lakukan untuk merawat dan memelihara benda koleksi?
# =====================================
# Proses Kalimat ke-75 dari 500
# Kalimat: Mengapa dokumen dan benda koleksi harus diplihaera?
# Hasil: Mengapa dokumen dan benda koleksi harus dilihera?
# =====================================
# Proses Kalimat ke-76 dari 500
# Kalimat: Bagaimana cara memelihara olkeksi piala?
# Hasil: Bagaimana cara memelihara koleksi piala?
# =====================================
# Proses Kalimat ke-77 dari 500
# Kalimat: Sebutkan apa saja yang termasuk benda kolkesi itu?
# Hasil: Sebutkan apa saja yang termasuk bendakolsesi itu.
# =====================================
# Proses Kalimat ke-78 dari 500
# Kalimat: Kamu pasti menuykai cerita.
# Hasil: Kamu pasti mnyukai cerita. -> Kamu pasti menyukai cerita.
# =====================================
# Proses Kalimat ke-79 dari 500
# Kalimat: Kamu juga asuk bercerita.
# Hasil: Kamu juga ikut bercerita.
# =====================================
# Proses Kalimat ke-80 dari 500
# Kalimat: Dokumen keluarga sebagai suembr cerita.
# Hasil: Dokumen keluarga sebagai cerita seru.
# =====================================
# Proses Kalimat ke-81 dari 500
# Kalimat: Bisakah kamu bercerita berdsaar dokumen keluarga?
# Hasil: Bisakah kamu bercerita tentang dokumen keluarga?
# =====================================
# Proses Kalimat ke-82 dari 500
# Kalimat: Suatu hari roni melihat album foto id lemari.
# Hasil: Suatu hari Roni melihat album foto di lemari.
# =====================================
# Proses Kalimat ke-83 dari 500
# Kalimat: Ternyata album itu besrii foto-foto dirinya.
# Hasil: Ternyata album itu bersisi foto-foto dirinya.
# =====================================
# Proses Kalimat ke-84 dari 500
# Kalimat: Ada fotonya ketika masih bayi sedang dignedong ibu.
# Hasil: Ada fotonya ketika masih bayi sedang digendong ibu.
# =====================================
# Proses Kalimat ke-85 dari 500
# Kalimat: Waktu itu roni arbu dilahirkan.
# Hasil: Waktu itu Rony Arbu dilahirkan.
# =====================================
# Proses Kalimat ke-86 dari 500
# Kalimat: Ada pula foto-foto lainnya bersama keluarga, ketkia roni masih kecil.
# Hasil: Ada pula foto-foto lainnya bersama keluarga, ketika roni masih kecil.
# =====================================
# Proses Kalimat ke-87 dari 500
# Kalimat: Kalau melihat foto, kita bisa mengenang amsa lalu.
# Hasil: Kalau melihat foto, kita bisa mengenang masa lalu.
# =====================================
# Proses Kalimat ke-88 dari 500
# Kalimat: Kamu bisa melihat dirimu ketika baru bermuur satu tahun.
# Hasil: Kamu bisa melihat dirimu ketika kamu baru berumur satu tahun.
# =====================================
# Proses Kalimat ke-89 dari 500
# Kalimat: Foto bisa mengingatkan kembali kenangan yang asudh kamu lupa.
# Hasil: Foto bisa mengingatkan kembali kenangan yang asuh kamu lupa.
# =====================================
# Proses Kalimat ke-90 dari 500
# Kalimat: Apakah kamu peranh difoto?
# Hasil: Apakah kamu telah difoto?
# =====================================
# Proses Kalimat ke-91 dari 500
# Kalimat: Di mana ukam difoto?
# Hasil: Di mana kamu difoto?
# =====================================
# Proses Kalimat ke-92 dari 500
# Kalimat: Dengan siapa ukam difoto?
# Hasil: Dengan siapa kamu difoto?
# =====================================
# Proses Kalimat ke-93 dari 500
# Kalimat: Foto harus disimpan deangn baik.
# Hasil: Foto harus disimpan dengan baik.
# =====================================
# Proses Kalimat ke-94 dari 500
# Kalimat: Guru membimbing anak agar mereka mengetahui iart dokumen dan macam-macam dokumen.
# Hasil: Guru membimbing anak agar mereka mengetahui arti dokumen dan macam-macam dokumen.
# =====================================
# Proses Kalimat ke-95 dari 500
# Kalimat: Guru memperlihatkan mcam-maacam dokumen.
# Hasil: Guru memperlihatkan contoh-contoh dokumen.
# =====================================
# Proses Kalimat ke-96 dari 500
# Kalimat: Ini adalah ftokou.
# Hasil: Ini adalah foto Anda.
# =====================================
# Proses Kalimat ke-97 dari 500
# Kalimat: Foto ini dibuat satu tahun yang ulal.
# Hasil: Foto ini dibuat satu tahun yang lalu.
# =====================================
# Proses Kalimat ke-98 dari 500
# Kalimat: Foto ini juga ditepeml diraporku.
# Hasil: Foto ini juga di terpemapilkan dalam raportku.
# =====================================
# Proses Kalimat ke-99 dari 500
# Kalimat: Kalau ini ofto keluargaku.
# Hasil: Kalau ini foto keluargaku.
# =====================================
# Proses Kalimat ke-100 dari 500
# Kalimat: Selain ada aku, ada ayah dan kibuu.
# Hasil: Selain ada aku, ada ayah dan buku.
# =====================================
# Proses Kalimat ke-101 dari 500
# Kalimat: Kakak dan adikku ugja ada.
# Hasil: Kakak dan adikku jugaa ada.
#
# Corrected: Kakak dan adikku sudah ada.
# =====================================
# Proses Kalimat ke-102 dari 500
# Kalimat: Bisakah kamu tunjukkan anyg mana diriku?
# Hasil: Bisakah kamu tunjukkan ayng mana diriku?
#
#  Corrected sentence:
# Bisakah kamu menunjukkan saya di mana?
# =====================================
# Proses Kalimat ke-103 dari 500
# Kalimat: Semua foto disimpan dengan baik oleh haya dan ibu.
# Hasil: Semua foto disimpan dengan baik oleh ayah dan ibu.
# =====================================
# Proses Kalimat ke-104 dari 500
# Kalimat: Suatu saat nanti foto akan jadi kennagan.
# Hasil: Suatu saat nanti foto akan menjadi kenangan.
# =====================================
# Proses Kalimat ke-105 dari 500
# Kalimat: Walaupun kamu nanti suhda besar.
# Hasil: Walaupun kamu nanti akan mendapat suhdah besar menjadi "Walaupun kamu nanti akan mendapatkan hadiah besar".
# =====================================
# Proses Kalimat ke-106 dari 500
# Kalimat: Kamu imash bisa melihat dirimu ketika masih bayi.
# Hasil: Kamu masih bisa melihat dirimu ketika kamu masih bayi.
# =====================================
# Proses Kalimat ke-107 dari 500
# Kalimat: Tanyakanlah kepada orang tuamu apakah mereka memliiki foto dirimu, misalnya foto ketika kamu bayi, ketika dikhitan, ketika ulang tahun, atau apa pun.
# Hasil: Tanyakanlah kepada orang tuamu apakah mereka memiliki foto dirimu, misalnya foto ketika kamu bayi, ketika khamilah khitan, ketika ulang tahun, atau apa pun.
# =====================================
# Proses Kalimat ke-108 dari 500
# Kalimat: Ceritankalah peristiwa yang ada di foto itu!
# Hasil: Ceritakalah peristiwa yang ada di foto itu!
# =====================================
# Proses Kalimat ke-109 dari 500
# Kalimat: Minta pula keapda orang tuamu fotomu pada saat sekarang.
# Hasil: Minta pula kepada orang tua mu foto mu pada saat sekarang.
# =====================================
# Proses Kalimat ke-110 dari 500
# Kalimat: Tempelkanlah foto tersebut pada pojok kreativitas gyan sudah disiapkan.
# Hasil: Tempelkanlah foto tersebut pada pojok kreatifitas guru sudah disiapkan.
#
# correction: kreatifitas -> kreativitas, guru -> gyn tidak ada karena yang benar adalah 'guru' jadi saran saya tidak mengubahnya menjadi gyan
# =====================================
# Proses Kalimat ke-111 dari 500
# Kalimat: Mintalah bantuan gurumu jika kamu mengalami kesluitan.
# Hasil: Mintaalah bantuan guru-mu jika kamu mengalami kesulitan.
# =====================================
# Proses Kalimat ke-112 dari 500
# Kalimat: Jangan lupa iber nama.
# Hasil: Jangan lupa beri nama.
# =====================================
# Proses Kalimat ke-113 dari 500
# Kalimat: Perhatikanlah otfomu dan foto kawan-kawan sekelasmu.
# Hasil: Perhatikanlah otfunganmu dan foto kawan-kawan sekalianmu.
# =====================================
# Proses Kalimat ke-114 dari 500
# Kalimat: Buatlah suatu pojok kreativitas di kelas sebgaai tempat untuk anak-anak menempelkan foto.
# Hasil: Buatlah suatu pojok kreativitas di kelas sebagai tempat untuk anak-anak menempelkan foto.
# =====================================
# Proses Kalimat ke-115 dari 500
# Kalimat: Pojok kreativitas bisa dihias oleh guru uata melibatkan anak-anak untuk menjadikannya lebih semarak dan menarik.
# Hasil: Pojok kreativitas bisa dihias oleh guru dengan melibatkan anak-anak untuk menjadikannya lebih semarak dan menarik.
#
# (Note: The transposition error was "uata" which should be "dengan")
# =====================================
# Proses Kalimat ke-116 dari 500
# Kalimat: Berilah judul atau tema pada pojok kretiviatas ini, misalnya "pojok diriku" atau "inilah aku".
# Hasil: Berikut adalah teks yang telah diperbaiki dengan memperhatikan prioritas transposisi:
#
# Berilah judul atau tema pada pojok kreativitas ini, misalnya "pojok diriku" atau "inilah aku".
# =====================================
# Proses Kalimat ke-117 dari 500
# 2000 di bandung, jawab raihan. tepatnya tanggal 12 oktober tahun
# Hasil: Aku lahir tanggal 21, tepatnya tanggal 12 Oktober tahun 2000 di Bandung, Jawaban adalah "raihan" bukan "jawab raihan".
#
# However, it seems there's a transposition error in the word order: "Jawaban" should be placed before the phrase.
#
# Aku lahir tanggal 21, tepatnya tanggal 12 Oktober tahun 2000 di Bandung, jawaban adalah raihan.
# =====================================
# Proses Kalimat ke-118 dari 500
# Kalimat: Namanya adalah akta kelhairan," kata raihan.
# Hasil: Namanya adalah akta kelahiran," kata Rahayu.
# =====================================
# Proses Kalimat ke-119 dari 500
# Kalimat: Ketika anak dilahirkan, dokter atau bidan memubat surat kelahiran.
# Hasil: Ketika anak dilahirkan, dokter atau bidan membubarkan surat kelahiran.
# =====================================
# Proses Kalimat ke-120 dari 500
# Kalimat: Lalu ayah melaporkannya kepada pak rt, pak rw, adn pak lurah.
# Hasil: Lalu ayah melaporkannya kepada Pak RT, Pak RW, dan Pak Lurah.
# =====================================
# Proses Kalimat ke-121 dari 500
# Kalimat: Kemudian ayah diberi sutra keterangan.
# Hasil: Kemudian ayah diberi keterangan sutra.
# =====================================
# Proses Kalimat ke-122 dari 500
# Kalimat: Surat keterangan itu dibawanya ke kantor ctataan sipil untuk dibuatkan akta kelahiran.
# Hasil: Surat keterangan itu dibawanya ke kantor catatan sipil untuk dibuatkan akta kelahiran.
# =====================================
# Proses Kalimat ke-123 dari 500
# Kalimat: Akta kelahiran disebut juga sebagai surat dtana kenal lahir.
# Hasil: Akta kelahiran disebut juga sebagai surat daftar lahir.
# =====================================
# Proses Kalimat ke-124 dari 500
# Kalimat: Semua orang memiliki ktaa kelahiran.
# Hasil: Semua orang memiliki ktaa ->  Semua orang memiliki akta kelahiran.
# =====================================
# Proses Kalimat ke-125 dari 500
# Kalimat: Akta kelahiran sanagt penting.
# Hasil: Akta kelahiran sangat penting.
# =====================================
# Proses Kalimat ke-126 dari 500
# Kalimat: Akta sangat banayk gunanya.
# Hasil: Akta sangat banyak gunanya.
# =====================================
# Proses Kalimat ke-127 dari 500
# Kalimat: Akta berguna untuk melajutnkan sekolah.
# Hasil: Akta berguna untuk melanjutkan sekolah.
# =====================================
# Proses Kalimat ke-128 dari 500
# Kalimat: Akta juga berguna unktu mencari pekerjaan.
# Hasil: Akta juga berguna untuk mencari pekerjaan.
# =====================================
# Proses Kalimat ke-129 dari 500
# Kalimat: Kalau kamu akan pergi ke luar ngerei, kamu memerlukan akta kelahiran.
# Hasil: Kalau kamu akan pergi ke luar negeri, kamu memerlukan akta kelahiran.
# =====================================
# Proses Kalimat ke-130 dari 500
# Kalimat: Perhtiakanlah akta kelahiran di bawah ini!
# Hasil: Perhatikanlah akta kelahiran di bawah ini!
# =====================================
# Proses Kalimat ke-131 dari 500
# Kalimat: Contoh lain yang termasuk dokumen adalah ktp, kartu keluraga, ijazah, dan sim.
# Hasil: Contoh lain yang termasuk dokumen adalah KTP, kartu keluarga, Ijazah, dan SIM.
# =====================================
# Proses Kalimat ke-132 dari 500
# Kalimat: Ktp singkatan dari kaurt tanda penduduk.
# Hasil: KTP singkatan dari Kartu Tanda Penduduk.
# =====================================
# Proses Kalimat ke-133 dari 500
# Kalimat: Setiap warga negara yang telah berumur 71 tahun harus  memiliki ktp.
# Hasil: Setiap warga negara yang telah berumur 17 tahun harus memiliki KTP.
# =====================================
# Proses Kalimat ke-134 dari 500
# Kalimat: Sim singkatan dari sutra ijin mengemudi.
# Hasil: Sim singkatan dari surat ijin mengemudi.
# =====================================
# Proses Kalimat ke-135 dari 500
# Kalimat: Sim harus dimiliki oleh semua pengendara omtor dan mobil.
# Hasil: Simak harus dimiliki oleh semua pengendara motor dan mobil.
# =====================================
# Proses Kalimat ke-136 dari 500
# Kalimat: Kartu kelaurga harus dimiliki oleh setiap keluarga.
# Hasil: Kartu keluarga harus dimiliki oleh setiap keluarga. (no error)
#
# However, I noticed a potential transposition error: "kelau" -> "kelu"
#
# Corrected sentence: Kartu keluarga harus dimiliki oleh setiap keluarga.
#
# Wait, there's no actual transposition error in this case!
# =====================================
# Proses Kalimat ke-137 dari 500
# Kalimat: Untuk membuat akta kelahiran dibutuhkan kartu kelaurga.
# Hasil: Untuk membuat akta kelahiran dibutuhkan Kartu Keluarga.
# =====================================
# Proses Kalimat ke-138 dari 500
# Kalimat: Apa manfaat ofto?
# Hasil: Apa manfaat foto?
# =====================================
# Proses Kalimat ke-139 dari 500
# Kalimat: Bagaimana cara menyimpan otfo yang baik?
# Hasil: Bagaimana cara menyimpan foto yang baik?
# =====================================
# Proses Kalimat ke-140 dari 500
# Kalimat: Siapakah yang membuat ktaa kelahiran?
# Hasil: Siapakah yang membuat kartu kelahiran?
# =====================================
# Proses Kalimat ke-141 dari 500
# Kalimat: Mengapa akta kelahiran snagat penting?
# Hasil: Mengapa akta kelahiran sangat penting?
# =====================================
# Proses Kalimat ke-142 dari 500
# Kalimat: Benda apa saja anyg termasuk dokumen?
# Hasil: Benda apa saja yang termasuk dokumen?
# =====================================
# Proses Kalimat ke-143 dari 500
# Kalimat: Mintalah foto kopi akta kelahiranmu pada norag tuamu.
# Hasil: Mintalah foto kopi akta kelahiranmu pada naragit tuamu.
# =====================================
# Proses Kalimat ke-144 dari 500
# Kalimat: Bawalah ke sekloah.
# Hasil: Bawalah ke sekolah.
# =====================================
# Proses Kalimat ke-145 dari 500
# Kalimat: Amatilah isinya, lalu isilah pertanyaan-pertanyaan di abwah ini.
# Hasil: Amatilah isinya, lalu isi lah pertanyaan-pertanyaan di bawah ini.
# =====================================
# Proses Kalimat ke-146 dari 500
# Kalimat: Hasilnya kumpulkan kepdaa gurumu.
# Hasil: Hasilnya kumpulkan kepada guru mu.
# =====================================
# Proses Kalimat ke-147 dari 500
# Kalimat: Siapakah nama lenkgapmu?
# Hasil: Siapakah nama lengkapmu?
# =====================================
# Proses Kalimat ke-148 dari 500
# Kalimat: Di manakah temapt kelahiranmu?
# Hasil: Di manakah tempat kelahiranmu?
# =====================================
# Proses Kalimat ke-149 dari 500
# Kalimat: Kapankah tanggal kelhiraanmu?
# Hasil: Kapankah tanggal lahirmu?
# =====================================
# Proses Kalimat ke-150 dari 500
# Kalimat: Siapakah nama ayamhu?
# Hasil: Siapakah nama ayamnya?
# =====================================
# Proses Kalimat ke-151 dari 500
# Kalimat: Siapakah nama mibuu?
# Hasil: Siapakah nama muibu?
# =====================================
# Proses Kalimat ke-152 dari 500
# Kalimat: Tanggal berapakah akta kelhairan itu dibuat?
# Hasil: Tanggal berapakah akte kelahiran itu dibuat?
# =====================================
# Proses Kalimat ke-153 dari 500
# Kalimat: Id manakah akta itu dibuat?
# Hasil: Id manakah itu akta dibuat?
# =====================================
# Proses Kalimat ke-154 dari 500
# Kalimat: Sekarang kita akan meumbat map dokumen.
# Hasil: Sekarang kita akan membaca map dokumen.
# =====================================
# Proses Kalimat ke-155 dari 500
# Kalimat: Tempelkanlah foto dirimu di bagian paling adepn map.
# Hasil: Tempelkanlah foto dirimu di bagian paling atas map.
# =====================================
# Proses Kalimat ke-156 dari 500
# Kalimat: Tempelkanlah foto-foto lainnya atau gambar-gambar lucu keskaanumu di bagian depan dan belakang map.
# Hasil: Tempelkanlah foto-foto lainnya atau gambar-gambar lucu kekesaanmu di bagian depan dan belakang map.
# =====================================
# Proses Kalimat ke-157 dari 500
# Kalimat: Jangan lupa sisakan bagian untuk menuliskan nmamau sendiri.
# Hasil: Jangan lupa sisakan bagian untuk menulis namamu sendiri.
# =====================================
# Proses Kalimat ke-158 dari 500
# Kalimat: Jika mau, buatlah judul untuk map teresbut sesukamu.
# Hasil: Jika mau, buatlah judul untuk makalah tersebut sesukamu.
# =====================================
# Proses Kalimat ke-159 dari 500
# Kalimat: Simpanlah foto kopi akta kelahiranmu di map buatanmu rsendii.
# Hasil: Simpanlah foto kopinya aktakelahiranmu di map buatannya sendiri.
# =====================================
# Proses Kalimat ke-160 dari 500
# Kalimat: Guru meminta dan mendorong anak untuk meneritakacn peristiwa berkesan yang pernah dialami anak.
# Hasil: Guru meminta dan mendorong anak untuk menceritakan peristiwa berkesan yang pernah dialami anak.
# =====================================
# Proses Kalimat ke-161 dari 500
# Kalimat: Deni tidak bosan memperhatinka fotonya.
# Hasil: Deni tidak bosan memperhatikan foto nya.
# =====================================
# Proses Kalimat ke-162 dari 500
# Kalimat: Foto itu terpasang di dinding dalam nruag keluarga.
# Hasil: Foto itu terpasang di dinding dalam ruang keluarga.
# =====================================
# Proses Kalimat ke-163 dari 500
# Kalimat: Di foto itu ia sedang memegang lpiaa didampingi ibunya.
# Hasil: Di foto itu ia sedang memegang lipiaa di dampingi ibunya.
# =====================================
# Proses Kalimat ke-164 dari 500
# Kalimat: Deni merasa sanagt bangga.
# Hasil: Deni merasa sangat bangga.
# =====================================
# Proses Kalimat ke-165 dari 500
# Kalimat: Saat itu deni mengtikui lomba sempoa.
# Hasil: Saat itu Deni mengikuti lomba sepak bola.
# =====================================
# Proses Kalimat ke-166 dari 500
# Kalimat: Deni ditunjuk mewkaili sekolahnya.
# Hasil: Deni ditunjuk mengkali sekolahnya.
# =====================================
# Proses Kalimat ke-167 dari 500
# Kalimat: Dien sangat gugup dan takut kalah.
# Hasil: Dien sangat gugup dan takut kalah.
#
# (no correction needed, but for perfection)
#
# Dien sangat gugup dan takut ia akan kalah.
# =====================================
# Proses Kalimat ke-168 dari 500
# Kalimat: Jantungnya berdetak sanagt keras.
# Hasil: Jantungnya berdetak sangat keras.
# =====================================
# Proses Kalimat ke-169 dari 500
# Kalimat: Tanpa disangka iden menang.
# Hasil: Tanpa disangka, ident menang.
# =====================================
# Proses Kalimat ke-170 dari 500
# Kalimat: Deni senang seklai.
# Hasil: Deni senang sekali.
# =====================================
# Proses Kalimat ke-171 dari 500
# Kalimat: Teman-teman dan guru berebutan untuk mengucapkan selmaat.
# Hasil: Teman-teman dan guru berebutan untuk mengucapkan salamat.
# =====================================
# Proses Kalimat ke-172 dari 500
# Kalimat: Peristiwa itu tidak akan pernah ia lupkaan.
# Hasil: Peristiwa itu tidak akan pernah ia lupakaan.
# =====================================
# Proses Kalimat ke-173 dari 500
# Kalimat: Kamu pun pasti memiliki peristiwa atau penalamgan yang berkesan.
# Hasil: Kamu pun pasti memiliki pengalaman yang berkesan.
# =====================================
# Proses Kalimat ke-174 dari 500
# Kalimat: Ceritakanlah di depan teman-temanmu peristiwa atau penalamgan berkesan yang pernah kamu alami itu.
# Hasil: Ceritakanlah di depan teman-temanmu peristiwa atau pengalaman berkesan yang pernah kamu alami itu.
# =====================================
# Proses Kalimat ke-175 dari 500
# Kalimat: Lewat foto itu pasya mengenang lagi amsa lalunya, ketika ia sedang dikhitan.
# Hasil: Lewat foto itu, pasya mengenang lagi masa laluinya, ketika ia sedang dikhitan menjadi "dihitung" salah satu transposisi, tapi lebih masuk akal adalah masa (masa lalu).
# =====================================
# Proses Kalimat ke-176 dari 500
# Kalimat: Ternyata dikhitan atidk sakit.
# Hasil: Ternyata diukhti an tidak sakit.
# =====================================
# Proses Kalimat ke-177 dari 500
# Kalimat: Peristiwa khitanan bagi anak laki-laki merupakan persitiwa besar.
# Hasil: Peristiwa khitanan bagi anak laki-laki merupakan peristiwa besar.
# =====================================
# Proses Kalimat ke-178 dari 500
# Kalimat: Lomba apakah yang diuikti deni?
# Hasil: Lomba apa yang diuji deni?
# =====================================
# Proses Kalimat ke-179 dari 500
# Kalimat: Apa yang terjadi setelah deni ditunjuk mewkaili sekolahnya?
# Hasil: Apa yang terjadi setelah Deni ditunjuk mengwajili sekolahnya?
#
#  Corrected:
# - Apa yang terjadi setelah Deni ditunjuk mengwajili -> ditunjuk menjabat
# - sekolahnya -> sekolah
#
# Corrected sentence:
#  Apa yang terjadi setelah deni ditunjuk menjabati sekolahnya?
# =====================================
# Proses Kalimat ke-180 dari 500
# Kalimat: Bagaimanakah perasaan deni etkika melihat fotonya?
# Hasil: Bagaimanakah perasaan Deni ketika melihat fotonya?
# =====================================
# Proses Kalimat ke-181 dari 500
# Kalimat: Foto apakah ayng diperlihatkan pasya kepada arman?
# Hasil: Foto apakah yang diperlihatkan pasyaa kepada arman?
# =====================================
# Proses Kalimat ke-182 dari 500
# Kalimat: Apakah pasya menangis etkika dikhitan?
# Hasil: Apakah paskah menangis ketika dikhitangi?
# =====================================
# Proses Kalimat ke-183 dari 500
# Kalimat: Foto termasuk dokmuen diri.
# Hasil: Foto termasuk dokumen diri.
# =====================================
# Proses Kalimat ke-184 dari 500
# Kalimat: Foto berguna untuk mengenang peristiwa dimasa ulal.
# Hasil: Foto berguna untuk mengenang peristiwa di masa lalu.
# =====================================
# Proses Kalimat ke-185 dari 500
# Kalimat: Akta kelahiran, kartu keluarga, ktp, ijazah, dan sim hadala dokumen penting.
# Hasil: Akta kelahiran, kartu keluarga, KTP, ijazah, dan SIM adalah dokumen penting.
# =====================================
# Proses Kalimat ke-186 dari 500
# Kalimat: Akta kelahiran disebut juga sebagai surat dtana kenal lahir seseorang.
# Hasil: Akta kelahiran disebut juga sebagai surat lahir dan akta kenal seseorang.
# =====================================
# Proses Kalimat ke-187 dari 500
# Kalimat: Dokumen penting harus dijaga dan dirawat denagn baik.
# Hasil: Dokumen penting harus dijaga dan dirawat dengan baik.
# =====================================
# Proses Kalimat ke-188 dari 500
# Kalimat: Apa sajakah yang termasuk dokumen penting kelaurga?
# Hasil: Apa sajakah yang termasuk dokumen penting keluarga?
# =====================================
# Proses Kalimat ke-189 dari 500
# Kalimat: Apakah alat yang digunakan untuk mengambil ofto?
# Hasil: Apakah alat yang digunakan untuk mengambil foto?
# =====================================
# Proses Kalimat ke-190 dari 500
# Kalimat: Sebutnka guna akta kelahiran?
# Hasil: Sebutkan guna akta kelahiran?
# =====================================
# Proses Kalimat ke-191 dari 500
# Kalimat: Pmengaa dokumen penting keluarga harus dijaga dan dirawat?
# Hasil: Pentingnya mengapa dokumen keluarga harus dijaga dan dirawat?
# =====================================
# Proses Kalimat ke-192 dari 500
# Kalimat: Dokumen apakah yang harus dimiliki pengendara omtor dan mobil?
# Hasil: Dokumen apakah yang harus dimiliki pengendara motor dan mobil?
# =====================================
# Proses Kalimat ke-193 dari 500
# Kalimat: Tiap keluarga punya periwstia penting.
# Hasil: Periwstia penting tiap keluarga punya.
# =====================================
# Proses Kalimat ke-194 dari 500
# Kalimat: Ada yang menenangkayn.
# Hasil: Ada yang menenangkan.
# =====================================
# Proses Kalimat ke-195 dari 500
# Kalimat: Ada yang menedihykan.
# Hasil: Ada yang mendehyikan.
# =====================================
# Proses Kalimat ke-196 dari 500
# Kalimat: Semuanya sangat berugna.
# Hasil: Semuanya sangat buruk.
# =====================================
# Proses Kalimat ke-197 dari 500
# Kalimat: Kita bisa iambl hikmahnya.
# Hasil: Kita bisa amabil hikmahnya.
# =====================================
# Proses Kalimat ke-198 dari 500
# Kalimat: Guru membimbing anak untuk mengetahui arti persitiwa.
# Hasil: Guru membimbing anak untuk mengetahui arti kejadian.
# =====================================
# Proses Kalimat ke-199 dari 500
# Kalimat: Guru juga membimbing dan mendorong anak untuk menceritakan peristaiw menyenangkan dalam keluarga.
# Hasil: Guru juga membimbing dan mendorong anak untuk menceritakan prestasi menyenangkan dalam keluarga.
# =====================================
# Proses Kalimat ke-200 dari 500
# Kalimat: Setiap orang mengalami peristiwa menyenangkan dalam hidpunya.
# Hasil: Setiap orang mengalami peristiwa menyenangkan dalam hidupnya.
# =====================================
# Proses Kalimat ke-201 dari 500
# Kalimat: Peristiwa yang pernah kita alami disebut penalamgan.
# Hasil: Peristiwa yang pernah kita alami disebut pengalaman.
# =====================================
# Proses Kalimat ke-202 dari 500
# Kalimat: Bgaiamana denganmu?
# Hasil: Bagaimana denganmu?
# =====================================
# Proses Kalimat ke-203 dari 500
# Kalimat: Apakah kamu juga memiliki peristiwa menyenangkan berasma keluarga?
# Hasil: Apakah kamu juga memiliki peristiwa menyenangkan bersama keluarga?
# =====================================
# Proses Kalimat ke-204 dari 500
# Kalimat: Ketika berumur enam tahun, ayah dan ibu memasukkan aold ke sekolah dasar atau sd.
# Hasil: Ketika berumur enam tahun, ayah dan ibu memasukkan anak ke sekolah dasar atau SD.
# =====================================
# Proses Kalimat ke-205 dari 500
# Kalimat: Aldo senang sekali karena di sd ilebh banyak teman.
# Hasil: Aldo senang sekali karena dia siswa SD di sana banyak teman.
# =====================================
# Proses Kalimat ke-206 dari 500
# Kalimat: Daa laki-laki dan ada perempuan.
# Hasil: Ada laki-laki dan ada perempuan.
# =====================================
# Proses Kalimat ke-207 dari 500
# Kalimat: Waktu pertama kali ke sekolah aldo diatnar ibu.
# Hasil: Waktu pertama kali ke sekolah, adikku (bukan "aldo") diajarkan ibu.
# =====================================
# Proses Kalimat ke-208 dari 500
# Kalimat: Lama-eklamaan aldo jadi berani pergi sendiri ke sekolah.
# Hasil: Lama-lamanya ado jadi berani pergi sendiri ke sekolah.
# =====================================
# Proses Kalimat ke-209 dari 500
# Kalimat: Karena sekolahnya dekat deangn rumah.
# Hasil: Karena sekolahnya dekat dengan rumah.
# =====================================
# Proses Kalimat ke-210 dari 500
# Kalimat: Pulangnya, aldo berjalan akki sendirian.
# Hasil: Pulangnya, Aldo berjalan sendirian ke akhir.
# =====================================
# Proses Kalimat ke-211 dari 500
# Kalimat: Di sekolah, aldo bejlaar bersama teman-teman.
# Hasil: Di sekolah,aldo belejar bersama teman-teman.
# =====================================
# Proses Kalimat ke-212 dari 500
# Kalimat: Aldo sangat senang bejlaar di kelas.
# Hasil: Aldo sangat senang belajar di kelas.
# =====================================
# Proses Kalimat ke-213 dari 500
# Kalimat: Emsua guru baik dan ramah.
# Hasil: Emusa guru baik dan ramah.
# =====================================
# Proses Kalimat ke-214 dari 500
# Kalimat: Ibu guru dan bapak guru selalu asbar membimbing aldo dan teman-teman.
# Hasil: Ibu guru dan bapak guru selalu asabar membimbing anak-anak (dapat juga menggunakan "aldo") dan teman-teman.
# =====================================
# Proses Kalimat ke-215 dari 500
# Kalimat: Aldo dan teman-teman adji rajin belajar.
# Hasil: Aldo dan teman-teman dia rajin belajar.
# =====================================
# Proses Kalimat ke-216 dari 500
# Kalimat: Astri merayakan ulang tahunyna yang kedelapan.
# Hasil: Astri merayakan ulang tahunya yang kedelapan.
# =====================================
# Proses Kalimat ke-217 dari 500
# Kalimat: Al mengundang teman-temannya ke rumah.
# Hasil: Al mengundang teman-teman ke rumahnya.
# =====================================
# Proses Kalimat ke-218 dari 500
# Kalimat: Semua teman menyanyikan lagu selamat ulang utahn sambil bertepuk tangan.
# Hasil: Semua teman menyanyikan lagu selamat ulang tahun sambil bertepuk tangan.
# =====================================
# Proses Kalimat ke-219 dari 500
# Kalimat: Astri meniup lilin ulang tahun, jumlahnya ada delapan bhua.
# Hasil: Astri meniup lilin ulang tahun, jumlahnya ada delapan buah.
# =====================================
# Proses Kalimat ke-220 dari 500
# Kalimat: Astri senang sekali karena orang tua dan semua temnnaya mengucapkan selamat.
# Hasil: Astri senang sekali karena orang tua dan semua teman-temannya mengucapkan selamat.
# =====================================
# Proses Kalimat ke-221 dari 500
# Kalimat: Ayah dan ibu mencium pipi dan kennig astri dengan sayang.
# Hasil: Ayah dan ibu mencium pipi dan kenangan istri dengan sayang.
# =====================================
# Proses Kalimat ke-222 dari 500
# Kalimat: La juga senang karena mendapatkan banyak okad.
# Hasil: Lagia senang karena mendapatkan banyak oka adla.
# =====================================
# Proses Kalimat ke-223 dari 500
# Kalimat: Kado sebagai hadiah ulgan tahun.
# Hasil: Kado sebagai hadiah ulang tahun.
# =====================================
# Proses Kalimat ke-224 dari 500
# Kalimat: Sii kado itu bermacam-macam.
# Hasil: Si ini kado itu bermacam-macam.
# =====================================
# Proses Kalimat ke-225 dari 500
# Kalimat: Ada boneka, alat tulis, tas, dan lai-nlain.
# Hasil: Ada boneka, alat tulis, tas, dan lain-lain.
# =====================================
# Proses Kalimat ke-226 dari 500
# Kalimat: Ahya dan ibu juga memberi kado untuk astri.
# Hasil: Ahya dan ibu juga memberi kado untuk astrid.
# =====================================
# Proses Kalimat ke-227 dari 500
# Kalimat: Isinya buku cerita anak bergambar yang ubags sekali.
# Hasil: Isinya buku cerita anak bergambar yang sangat sekali.
# =====================================
# Proses Kalimat ke-228 dari 500
# Kalimat: Stari mengucapkan terima kasih kepada ayah dan ibu.
# Hasil: Terima kasih kepada ayah dan ibu, stari mengucapkan terima kasih.
# =====================================
# Proses Kalimat ke-229 dari 500
# Kalimat: Sewaktu nabila berumur enam tahun, ibu melhirkaan adik bayi.
# Hasil: Sewaktu Nabila berumur enam tahun, ibu melahirkan adik bayi.
# =====================================
# Proses Kalimat ke-230 dari 500
# Kalimat: Adik bayi itu laki-laki dan diberi anma lintang.
# Hasil: Adik bayi itu laki-laki dan diberi nama lintang.
# =====================================
# Proses Kalimat ke-231 dari 500
# Kalimat: Nlitang sangat lucu dan sering ngompol.
# Hasil: Lintang sangat lucu dan sering ngomong.
# =====================================
# Proses Kalimat ke-232 dari 500
# Kalimat: Nabila sering membantu ibu mengganti popok linatng.
# Hasil: Nabila sering membantu ibu mengganti popok linitng.
# =====================================
# Proses Kalimat ke-233 dari 500
# Kalimat: Nabila sangat sayang kedpaa lintang.
# Hasil: Nabila sangat sayang kepada lintang.
# =====================================
# Proses Kalimat ke-234 dari 500
# Kalimat: Sejak ada lintang, nabila tidak merasa ksepeian lagi.
# Hasil: Sejak ada lintang, Nabila tidak merasa kepuasan lagi.
# =====================================
# Proses Kalimat ke-235 dari 500
# Kalimat: Rendi mengikuti lomba menyanyi antar sekolah adsar di kotanya.
# Hasil: Rendi mengikuti lomba menyanyi antar sekolah dasar di kotanya.
# =====================================
# Proses Kalimat ke-236 dari 500
# Kalimat: La mewakili seklahnoya.
# Hasil: La mewakili sekolahnya.
# =====================================
# Proses Kalimat ke-237 dari 500
# Kalimat: Lomba itu diikuti oleh ratusan siswa gyan berasal dari beberapa sekolah dasar.
# Hasil: Lomba itu diikuti oleh ratusan siswa yang berasal dari beberapa sekolah dasar.
# =====================================
# Proses Kalimat ke-238 dari 500
# Kalimat: Awalnya rendi sanagt gugup.
# Hasil: Awalnya Rendi sangat gugup.
# =====================================
# Proses Kalimat ke-239 dari 500
# Kalimat: La takut sekali kaula kalah.
# Hasil: La takut sekali kaula menjadi "kita" dan "kalah" tidak ada perubahan, namun saya akan memperbaiki sedikit agar kalimat lebih benar dan mudah dipahami.
#
# La takut sekali kita kalah bisa menjadi La takut sekali kita kalah tetapi lebih baik: Kami sangatlah takut kita akan kalah
# =====================================
# Proses Kalimat ke-240 dari 500
# Kalimat: Rendi takut mengecewakan urgu dan teman-temannya.
# Hasil: Rendi takut mengecewakan guru dan teman-temannya.
# =====================================
# Proses Kalimat ke-241 dari 500
# Kalimat: Akhirnya pak anwar menasihati rendi supaya atidk usah gugup dan takut kalah.
# Hasil: Akhirnya pak Anwar menasihati Rendi supaya tidak usah gugup dan takut kalah.
# =====================================
# Proses Kalimat ke-242 dari 500
# Kalimat: Pak anwar adalah wali kelas renid di sekolah.
# Hasil: Pak Anwar adalah wali kelas rendi di sekolah.
# =====================================
# Proses Kalimat ke-243 dari 500
# Kalimat: Pak anwar bilang kalah itu tidak apaa-pa asalkan kita sudah berusaha sebaik mungkin.
# Hasil: Pak Anwar bilang kalah itu tidak apa-apa asalkan kita sudah berusaha sebaik mungkin.
# =====================================
# Proses Kalimat ke-244 dari 500
# Kalimat: Kekalahan bisa dijadikan peljaaran nantinya.
# Hasil: Kekalahan bisa dijadikan pelajaran nantinya.
# =====================================
# Proses Kalimat ke-245 dari 500
# Kalimat: Setelah mendengar nasihat pak anwar, rendi mersaa tenang dan bisa menyanyi dengan baik.
# Hasil: Setelah mendengar nasihat Pak Anwar, Rendi merasa tenang dan bisa menyanyi dengan baik.
# =====================================
# Proses Kalimat ke-246 dari 500
# Kalimat: Tanpa disangka rendi meanjdi juara pertama.
# ...
# =====================================
# Proses Kalimat ke-418 dari 500
# Kalimat: Semua perilaku yang aibk harus ditingkatkan.
# Hasil: Semua perilaku yang baik harus ditingkatkan.
# =====================================
# Proses Kalimat ke-419 dari 500
# Kalimat: Sebaliknya perilaku yang tidak baik seharusnya dtinggalkain.
# Hasil: Sebaliknya perilaku yang tidak baik seharusnya ditinggalkan.
# =====================================
# Proses Kalimat ke-420 dari 500
# Kalimat: Perilaku yang tidak baik tidak boleh dbiairkan.
# Hasil: Perilaku yang tidak baik tidak boleh dibicarakan.
# =====================================
# Proses Kalimat ke-421 dari 500
# Kalimat: Perilaku yang baik membuat diri sendiri dan orang lnai senang.
# Hasil: Perilaku yang baik membuat diri sendiri dan orang lain senang.
# =====================================
# Proses Kalimat ke-422 dari 500
# Kalimat: Anak yang memiliki perilaku baik disayangi norag tua, guru, dan teman-teman.
# Hasil: Anak yang memiliki perilaku baik disayangi oleh orang tua, guru, dan teman-teman.
#
# ( Transposed "norag" to "orang")
# =====================================
# Proses Kalimat ke-423 dari 500
# Kalimat: Apakah kamu ingin disegnani orang lain?
# Hasil: Apakah kamu ingin digunakan orang lain?
# =====================================
# Proses Kalimat ke-424 dari 500
# Kalimat: Mengapa arina selalu ranji belajar?
# Hasil: Mengapa Aria selalu meranjis belajar?
# =====================================
# Proses Kalimat ke-425 dari 500
# Kalimat: Apa yang dilakukan arina selain rajin beljaar?
# Hasil: Apa yang dilakukan Arina selain rajin belajar?
# =====================================
# Proses Kalimat ke-426 dari 500
# Kalimat: Apa gyan harus dilakukan dengan perilaku yang baik?
# Hasil: Apa gaya harus dilakukan dengan perilaku yang baik?
# =====================================
# Proses Kalimat ke-427 dari 500
# Kalimat: Apa gyan harus dilakukan dengan perilaku yang buruk atau tidak baik?
# Hasil: Apa gaya harus dilakukan dengan perilaku yang buruk atau tidak baik?
# =====================================
# Proses Kalimat ke-428 dari 500
# Kalimat: Bagaimana akibatnya jika kita memiliki perilaku gyan baik?
# Hasil: Bagaimana akibatnya jika kita memiliki perilaku yang baik?
# =====================================
# Proses Kalimat ke-429 dari 500
# Kalimat: Cermatilah perilaku di bahwa ini!
# Hasil: Cermatilah perilaku di ini! -> Cermati perilaku di sini!
#
# Corrected sentence: Cermati perilaku di sini!
# =====================================
# Proses Kalimat ke-430 dari 500
# Kalimat: Diskusikan dengan temanmu apakah perilaku ini uhars diperbaiki, ditingkatkan, atau dipertahankan.
# Hasil: Diskusikan dengan temanmu apakah perilaku ini harus diperbaiki, ditingkatkan, atau dipertahankan.
# =====================================
# Proses Kalimat ke-431 dari 500
# Kalimat: Hasilnya dikumpulkan kepdaa gurumu.
# Hasil: Hasilnya dikumpulkan kepada guru mu.
# =====================================
# Proses Kalimat ke-432 dari 500
# Kalimat: Setiap orang memiliki peristiwa penting dalam hidpunya.
# Hasil: Setiap orang memiliki peristiwa penting dalam hidupnya.
# =====================================
# Proses Kalimat ke-433 dari 500
# Kalimat: Peristiwa itu ada ygan menyenangkan dan ada pula yang tidak menyenangkan.
# Hasil: Peristiwa itu ada yang menyenangkan dan ada pula yang tidak menyenangkan.
# =====================================
# Proses Kalimat ke-434 dari 500
# Kalimat: Semua peristiwa dapat diurutkan berdasarkan waktu teradinjya.
# Hasil: Semua peristiwa dapat diurutkan berdasarkan waktu terjadiannya.
# =====================================
# Proses Kalimat ke-435 dari 500
# Kalimat: Peristiwa di masa lalu memiliki pengaruh terahdap peristiwa masa kini.
# Hasil: Peristiwa di masa lalu memiliki pengaruh terhadap peristiwa masa kini.
# =====================================
# Proses Kalimat ke-436 dari 500
# Kalimat: Perilaku itu ada yang arhus ditingkatkan, ada yang harus diperbaiki, dan ada yang harus ditinggalkan.
# Hasil: Perilaku itu ada yang harus ditingkatkan, ada yang harus diperbaiki, dan ada yang harus ditinggalkan.
# =====================================
# Proses Kalimat ke-437 dari 500
# Kalimat: Seperti apakah contoh periwstia menyenangkan?
# Hasil: Periwstia -> Peristiwa
# Contoh periwstia -> Contoh peristiwa
#
# Result:
# Seperti apakah contoh peristiwa menyenangkan?
# =====================================
# Proses Kalimat ke-438 dari 500
# Kalimat: Seperti apakah contoh periwstia menyedihkan itu?
# Hasil: Seperti apakah contoh peristiwa menyedihkan itu?
# =====================================
# Proses Kalimat ke-439 dari 500
# Kalimat: Sebutkan perilaku yang hasru ditingkatkan?
# Hasil: Sebutkan perilaku yang harus ditingkatkan?
# =====================================
# Proses Kalimat ke-440 dari 500
# Kalimat: Apakah kamu pernah masla belajar?
# Hasil: Apakah kamu pernah belajar malsa?
# =====================================
# Proses Kalimat ke-441 dari 500
# Kalimat: Paa yang kamu lakukan untuk memperbaikinya?
# Hasil: Pada yang kamu lakukan untuk memperbaikinya?
# =====================================
# Proses Kalimat ke-442 dari 500
# Kalimat: Tiap organ punya orang tua.
# Hasil: Tiap orang punya organ tua.
# =====================================
# Proses Kalimat ke-443 dari 500
# Kalimat: Karena itu, dapat diabut silsilah.
# Hasil: Karena itu, silsilah dapat dibuat.
# =====================================
# Proses Kalimat ke-444 dari 500
# Kalimat: Kamu harus tahu slsilaih keluargamu.
# Hasil: Kamu harus tahu silsilaih keluargamu.
# =====================================
# Proses Kalimat ke-445 dari 500
# Kalimat: Kamu harus tahu keduadukn anak.
# Hasil: Kamu harus tahu kedua dukun anak.
# =====================================
# Proses Kalimat ke-446 dari 500
# Kalimat: Kamu harus tahu keduadukn orang tua.
# Hasil: Kamu harus tahu kedua orang tua.
# =====================================
# Proses Kalimat ke-447 dari 500
# Kalimat: Kamu juga harus tahu peran anggota kelaurga.
# Hasil: Kamu juga harus tahu peran anggota keluarga.
# =====================================
# Proses Kalimat ke-448 dari 500
# Kalimat: Guru membimbing anak untuk mengetahui arti ilsislah keluarga dan dapat menceritakan silsilah keluarganya.
# Hasil: Guru membimbing anak untuk mengetahui arti isilah keluarga dan dapat menceritakan silsilah keluarganya.
# =====================================
# Proses Kalimat ke-449 dari 500
# Kalimat: Silsilah keluarga dimiliki seatip keluarga.
# Hasil: Silsilah keluarga dimiliki tiap keluarga.
# =====================================
# Proses Kalimat ke-450 dari 500
# Kalimat: Silsilah keluarga artinya asalu-sul keluarga.
# Hasil: Silsilah keluarga artinya suku-suku keluarga.
# =====================================
# Proses Kalimat ke-451 dari 500
# Kalimat: Keluargamu tentu juga memiikli silsilah keluarga.
# Hasil: Keluargamu tentu juga memilih silsilah keluarga.
# =====================================
# Proses Kalimat ke-452 dari 500
# Kalimat: Aki rahmat dan nini ratna adalah norag tua ayahku.
# Hasil: Aki rahmat dan Nini Ratna adalah narag tua ayahku.
#
# Corrected sentence:
# Nini Ratna dan Aki Rahmat adalah ayahanda saya.
# =====================================
# Proses Kalimat ke-453 dari 500
# Kalimat: Ayahku adalah orang sunda, jadi kakek dan nenekku dipanglgi aki dan nini.
# Hasil: Ayahku adalah orang Sunda, jadi kakek dan nenekku dipanggil aki dan nini.
# =====================================
# Proses Kalimat ke-454 dari 500
# Kalimat: Eyang kakung argo dan eyang putri mlasi adalah orang tua ibuku.
# Hasil: Eyang Kakung Argo dan Eyang Putri Mauliati adalah orang tua ibuku.
# =====================================
# Proses Kalimat ke-455 dari 500
# Kalimat: Ibuku adalah norag jawa.
# Hasil: Ibuku adalah orang Jawa.
# =====================================
# Proses Kalimat ke-456 dari 500
# Kalimat: Kakek disebut dengan eyang kakung dan ennek disebut dengan eyang putri.
# Hasil: Kakek disebut dengan eyang kakung dan ende disebut dengan eyang putri.
# =====================================
# Proses Kalimat ke-457 dari 500
# Kalimat: Jiad aku memiliki dua kakek dan dua nenek.
# Hasil: Jika aku memiliki dua kakek dan dua nenek.
# =====================================
# Proses Kalimat ke-458 dari 500
# Kalimat: Ayah adalah anak bungsu dan memiliki usat kakak, namanya sarah.
# Hasil: Ayah adalah anak bungsu dan memiliki saudara kakak, namanya Sarah.
# =====================================
# Proses Kalimat ke-459 dari 500
# Kalimat: Aku memanggilnya kuwa sarah.
# Hasil: Aku memanggilnya adalah Sarah.
# =====================================
# Proses Kalimat ke-460 dari 500
# Kalimat: Uwak sarah menikah deangn uwak tanto.
# Hasil: Uwak Saran menikah dengan uwak Tanto.
# =====================================
# Proses Kalimat ke-461 dari 500
# Kalimat: Amerek memiliki dua anak, yaitu nindi dan hari.
# Hasil: - User: Amerek memiliki dua anak, yaitu nindi dan hari.
# - Assistant: Amerika memiliki dua anak, yaitu India dan Hari.
# =====================================
# Proses Kalimat ke-462 dari 500
# Kalimat: Mereka adalah seppuuku.
# Hasil: Mereka adalah sepupu.
# =====================================
# Proses Kalimat ke-463 dari 500
# Kalimat: Ibuku memiliki saudara kembar, namanya tante arin.
# Hasil: Ibuku memiliki saudara kembar, nama nya adalah Tante Arin.
# =====================================
# Proses Kalimat ke-464 dari 500
# Kalimat: Wajah ibu dan tante rina sangat imrip.
# Hasil: Wajah ibu dan tante Rina sangat iri.
# =====================================
# Proses Kalimat ke-465 dari 500
# Kalimat: Tante rina menikah dengan om wandi itap mereka belum punya anak.
# Hasil: Tante Rina menikah dengan Om Wandi itu, mereka belum punya anak.
# =====================================
# Proses Kalimat ke-466 dari 500
# Kalimat: Seperti ibuku, aku ugja anak kembar.
# Hasil: Seperti ibuku, aku adalah anak kembar.
# =====================================
# Proses Kalimat ke-467 dari 500
# Kalimat: Saudara kembarku nmanaya irna.
# Hasil: Saudara kembar-ku, mana ya irina?
# =====================================
# Proses Kalimat ke-468 dari 500
# Kalimat: Namaku adalah airm.
# Hasil: Nama ku adalah Aria.
# =====================================
# Proses Kalimat ke-469 dari 500
# Kalimat: Orang sering bingung menglenai kami.
# Hasil: Orang sering bingung mengenal kami.
# =====================================
# Proses Kalimat ke-470 dari 500
# Kalimat: Aku juga punya diak, namanya tomi.
# Hasil: Aku juga punya adik, nama saya Tomi.
# =====================================
# Proses Kalimat ke-471 dari 500
# Kalimat: Tomi masih baltia.
# Hasil: Tomi masih Bali.
# =====================================
# Proses Kalimat ke-472 dari 500
# Kalimat: Apa artinya silsilah kelurgaa itu?
# Hasil: Apa artinya silsilah keluarga itu?
# =====================================
# Proses Kalimat ke-473 dari 500
# Kalimat: Silsilah keluarga siapakah anyg diceritakan tadi?
# Hasil: Silislah keluarga siapakah yang diceritakan tadi?
# =====================================
# Proses Kalimat ke-474 dari 500
# Kalimat: Sebutkan nama ekakk irma?
# Hasil: Sebutkan nama ikarima.
# =====================================
# Proses Kalimat ke-475 dari 500
# Kalimat: Siapahka orang tua nindi?
# Hasil: Siapa haka orang tua itu?
# =====================================
# Proses Kalimat ke-476 dari 500
# Kalimat: Siapakah saudara kembar ibu dan siapakah suaimnya?
# Hasil: Siapakah saudara kembar ibu dan siapakah suaminya?
# =====================================
# Proses Kalimat ke-477 dari 500
# Kalimat: Buatlah silsilah keluargamu seindri seperti contoh.
# Hasil: Buatlah silsilah keluargamu seperti contoh seindari.
# =====================================
# Proses Kalimat ke-478 dari 500
# Kalimat: Tanyakan pada norag tuamu.
# Hasil: Tanyakan pada nagor tuamu.
# =====================================
# Proses Kalimat ke-479 dari 500
# Kalimat: Ceritakanlah kepada teman-temanmu di kelas tentang ilsislah keluargamu.
# Hasil: Ceritakanlah kepada teman-temanmu di kelas tentang ilmu sihlah keluargamu.
# =====================================
# Proses Kalimat ke-480 dari 500
# Kalimat: Secara umum guru menerangkan kedudukan serta apern semua anggota keluarga.
# Hasil: Secara umum guru menerangkan kedudukan serta peran semua anggota keluarga.
# =====================================
# Proses Kalimat ke-481 dari 500
# Kalimat: Lebih baik jika guru menjelaskan dengan memebri contoh menggunakan alat peraga, misalnya foto satu keluarga (tergantung kreativitas guru).
# Hasil: Lebih baik jika guru menjelaskan dengan memberi contoh menggunakan alat peraga, misalnya foto satu keluarga (tergantung kreativitas guru).
# =====================================
# Proses Kalimat ke-482 dari 500
# Kalimat: Bimbinglah anak supaya mengetahui peran dan keddukannyua sendiri dalam keluarga.
# Hasil: Bimbinglah anak supaya mengetahui peran dan kepadudukannya sendiri dalam keluarga.
#
# Corrected sentence:
#  Bimbinglah anak supaya mengetahui peran dan kedudukan sendiri dalam keluarga.
# =====================================
# Proses Kalimat ke-483 dari 500
# Kalimat: Setiap orang mempunyai keluarga, seperti juga ukam.
# Hasil: Setiap orang mempunyai keluarga, seperti juga kamu.
# =====================================
# Proses Kalimat ke-484 dari 500
# Kalimat: Di dalam keluarga biasanya terdiri dari bbereapa orang, misalnya ada ayah, ibu, nenek, kakek, kakak, adik, dan lain-lain.
# Hasil: Di dalam keluarga biasanya terdiri dari berapa banyak orang, misalnya ada ayah, ibu, nenek, kakek, kakak, adik, dan lain-lain.
#
# (Korrek: "berapa" dan "banyak" adalah kata yang sangat mirip dan sering digunakan secara tidak tepat)
# =====================================
# Proses Kalimat ke-485 dari 500
# Kalimat: Coba sebutkan ada siapa saja di rumhamu?
# Hasil: Coba sebutkan ada siapa saja di rumahmu?
# =====================================
# Proses Kalimat ke-486 dari 500
# Kalimat: Semua anggota keluarga mempaunyi kedudukan.
# Hasil: Semua anggota keluarga mempunyai kedudukan.
# =====================================
# Proses Kalimat ke-487 dari 500
# Kalimat: Kedudukan setiap anggota kelurgaa berbeda.
# Hasil: Kedudukan setiap anggota keluarga berbeda.
# =====================================
# Proses Kalimat ke-488 dari 500
# Kalimat: Ini adalah kelaurga andrea.
# Hasil: Kelaurga ini adalah Andrea.
# =====================================
# Proses Kalimat ke-489 dari 500
# Kalimat: Jumlah anggota keluarga andrea ada lima norag.
# Hasil: Jumlah anggota keluarga Andrea ada lima orang.
# =====================================
# Proses Kalimat ke-490 dari 500
# Kalimat: Yaitu ayah, ibu, kakak, andrea, dan kadi.
# Hasil: Yaitu ayah, ibu, kakak, Andrea, dan adik.
# =====================================
# Proses Kalimat ke-491 dari 500
# Kalimat: Andrea adalah anak kedua dari tiga beraudasra.
# Hasil: Andrea adalah anak kedua dari tiga beradatrasa.
# =====================================
# Proses Kalimat ke-492 dari 500
# Kalimat: Kakak andrea nmanaya pasya.
# Hasil: Kakak Andrea, mana ya pasnya?
# =====================================
# Proses Kalimat ke-493 dari 500
# Kalimat: Pasya adalah kana pertama.
# Hasil: Pasa adalah kana pertama.
# =====================================
# Proses Kalimat ke-494 dari 500
# Kalimat: Dimi adalah kadi andrea.
# Hasil: Dimi adalah kadi Andrea.
# =====================================
# Proses Kalimat ke-495 dari 500
# Kalimat: Ahya andrea namanya pak aswan.
# Hasil: Andi Ahya namanya Pak Aswan.
# =====================================
# Proses Kalimat ke-496 dari 500
# Kalimat: Apk aswan adalah kepala keluarga, suami, dan ayah.
# Hasil: Apakah aswannya adalah kepala keluarga, suami, dan ayah.
# =====================================
# Proses Kalimat ke-497 dari 500
# Kalimat: Ibunda andrea beranma intan.
# Hasil: Ibunda Andrea bermain intan.
# =====================================
# Proses Kalimat ke-498 dari 500
# Kalimat: Sehari-hari dipanggil bu aswan karena ibu adaalh istri pak aswan.
# Hasil: Sehari-hari dipanggil Bu Aswan karena Ibu adalah istri Pak Aswan.
# =====================================
# Proses Kalimat ke-499 dari 500
# Kalimat: Guru menerangkan tentang kedudukan orang tua adlam keluarga.
# Hasil: Guru menerangkan tentang kedudukan orang tua dalam keluarga.
# =====================================
# Proses Kalimat ke-500 dari 500
# Kalimat: Munculkan rasa hormat anak terhadap orang tuayna.
# Hasil: Munculkan rasa hormat anak terhadap orang tua-nya.
# =====================================
# ====== Selesai Proses  ======

# %% [markdown]
# ## 5. Evaluasi & Visualisasi Akurasi

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hitung akurasi dengan kedua skema
exact_acc, exact_detail = skema_exact_match(hasil_llm_model, kalimat_benar)
kata_acc, kata_detail = skema_kata_per_kata(hasil_llm_model, kalimat_benar)

# Tampilkan hasil akurasi
print(f"====== Hasil Evaluasi ======")
print(f"Skema 1 - Exact Match Accuracy : {exact_acc:.4f}")
print(f"Skema 2 - Word Match Accuracy  : {kata_acc:.4f}")
print(f"Rata-rata waktu proses         : {np.mean(processing_times):.2f}s")

# Buat dataframe untuk menyimpan hasil detail
results_data = []
for i, (salah, benar, hasil, exact, kata_akurasi, process_time) in enumerate(zip(kalimat_salah, kalimat_benar, hasil_llm_model, exact_detail, kata_detail, processing_times)):
    status = "✓" if exact else "✗"
    results_data.append({
        'no': i+1,
        'exact_match': exact,
        'word_accuracy': kata_akurasi,
        'input_sentence': salah,
        'target_sentence': benar,
        'llm_output': hasil,
        'processing_time': process_time
    })
    
    # Print untuk output konsol
    print(f"{i+1}. {status} Kata Benar: {kata_akurasi:.2f}")
    print(f"   Input : {salah}")
    print(f"   Target: {benar}")
    print(f"   LLM   : {hasil}")
    print(f"   Waktu Proses: {process_time:.2f}s\n")

# Buat DataFrame dari hasil
df_results = pd.DataFrame(results_data)

# Simpan ke CSV
output_filename = f"{uploaded_filename}_hasil_koreksi_ejaan.csv"
df_results.to_csv(output_filename, index=False)
print(f"\nHasil detail telah disimpan ke file: {output_filename}")

# Simpan juga ringkasan hasil
summary_data = {
    'Model': [selected_model],
    'Exact_Match_Accuracy': [exact_acc],
    'Word_Match_Accuracy': [kata_acc],
    'Avg_Processing_Time': [np.mean(processing_times)]
}
df_summary = pd.DataFrame(summary_data)
summary_filename = f"{uploaded_filename}_ringkasan_akurasi.csv"
df_summary.to_csv(summary_filename, index=False)
print(f"Ringkasan hasil telah disimpan ke file: {summary_filename}")

# Visualisasi tetap sama seperti sebelumnya
metrics = ['Exact Match', 'Word Match']
values = [exact_acc, kata_acc]
colors = ['blue', 'green']

plt.figure(figsize=(10, 6))
bars = plt.bar(metrics, values, color=colors)
plt.ylim(0, 1.0)
plt.title('Akurasi Koreksi Ejaan dengan LLM')
plt.ylabel('Akurasi')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Tambahkan label nilai di atas bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.02,
            f'{height:.2f}', ha='center', va='bottom')

plt.tight_layout()

# Save the figure before showing it
filename = f"{uploaded_filename}_accuracy.png"
plt.savefig(filename, bbox_inches='tight', dpi=300)
plt.show()
# Out:
# ====== Hasil Evaluasi ======
# Skema 1 - Exact Match Accuracy : 0.3760
# Skema 2 - Word Match Accuracy  : 0.7636
# Rata-rata waktu proses         : 0.30s
# 1. ✓ Kata Benar: 1.00
#    Input : Tiap orang punya beand berharga.
#    Target: Tiap orang punya benda berharga.
#    LLM   : Tiap orang punya benda berharga.
#    Waktu Proses: 0.19s
#
# 2. ✗ Kata Benar: 0.00
#    Input : Bisa juga berpua benda-benda.
#    Target: Bisa juga berupa benda-benda.
#    LLM   : Benda-benda bisa juga berpuas.
#    Waktu Proses: 0.18s
#
# 3. ✗ Kata Benar: 0.80
#    Input : Edokumn harus dijaga dan dirawat.
#    Target: Dokumen harus dijaga dan dirawat.
#    LLM   : Edokumen harus dijaga dan dirawat.
#    Waktu Proses: 0.19s
#
# 4. ✓ Kata Benar: 1.00
#    Input : Benda berharga juga hasru dipelihara.
#    Target: Benda berharga juga harus dipelihara.
#    LLM   : Benda berharga juga harus dipelihara.
#    Waktu Proses: 0.19s
#
# 5. ✓ Kata Benar: 1.00
#    Input : Jika dirawat, dokumen dan benda berharga atidk mudah rusak.
#    Target: Jika dirawat, dokumen dan benda berharga tidak mudah rusak.
#    LLM   : Jika dirawat, dokumen dan benda berharga tidak mudah rusak.
#    Waktu Proses: 0.30s
#
# 6. ✗ Kata Benar: 0.89
#    Input : Guru membimbing anak untuk mengetahui pentingnya mmelihaera dokumen dan koleksi benda berharga diri dan keluarga, sehingga anak bisa menghargainya.
#    Target: Guru membimbing anak untuk mengetahui pentingnya memelihara dokumen dan koleksi benda berharga diri dan keluarga, sehingga anak bisa menghargainya.
#    LLM   : Guru membimbing anak untuk mengetahui pentingnya menejaha dokumen dan koleksi benda berharga diri dan keluarga, sehingga anak bisa menghargaiinya.
#    Waktu Proses: 0.68s
#
# 7. ✓ Kata Benar: 1.00
#    Input : Guru juga mengenalkan dan menunjukkan contoh dbena koleksi.
#    Target: Guru juga mengenalkan dan menunjukkan contoh benda koleksi.
#    LLM   : Guru juga mengenalkan dan menunjukkan contoh benda koleksi.
#    Waktu Proses: 0.30s
#
# 8. ✗ Kata Benar: 0.91
#    Input : Suatu hari fadilah melihat ibu menyusun dokmuen penting dalam map plastik.
#    Target: Suatu hari fadilah melihat ibu menyusun dokumen penting dalam map plastik.
#    LLM   : Suatu hari Fadillah melihat ibu menyusun dokumen penting dalam map plastik.
#    Waktu Proses: 0.38s
#
# 9. ✗ Kata Benar: 0.83
#    Input : Ada akta kelahiran, kartu keluarga, surat atnah, ijazah, dan surat dari eyang.
#    Target: Ada akta kelahiran, kartu keluarga, surat tanah, ijazah, dan surat dari eyang.
#    LLM   : Ada akta kelahiran, kartu keluarga, surat keterangan, ijazah, dan surat dari kakek.
#    Waktu Proses: 0.48s
#
# 10. ✗ Kata Benar: 0.86
#    Input : Di amplop surat itu masih tertempel perngkoanya.
#    Target: Di amplop surat itu masih tertempel perangkonya.
#    LLM   : Di amplop surat itu masih tertempel stempelnya.
#    Waktu Proses: 0.26s
#
# 11. ✓ Kata Benar: 1.00
#    Input : Ibu juga menyusun foo-tfoto dalam album.
#    Target: Ibu juga menyusun foto-foto dalam album.
#    LLM   : Ibu juga menyusun foto-foto dalam album.
#    Waktu Proses: 0.21s
#
# 12. ✗ Kata Benar: 0.83
#    Input : Di ruang tamu fadilah melihat ayah memersihkabn dan membereskan piala di lemari.
#    Target: Di ruang tamu fadilah melihat ayah membersihkan dan membereskan piala di lemari.
#    LLM   : Di ruang tamu, Fadilah melihat ayah membersihkan dan membersihkan piala di lemari.
#    Waktu Proses: 0.45s
#
# 13. ✗ Kata Benar: 0.75
#    Input : Ayah membersihkan lpiaa itu.
#    Target: Ayah membersihkan piala itu.
#    LLM   : Ayah membersihkan lipat itu.
#    Waktu Proses: 0.17s
#
# 14. ✓ Kata Benar: 1.00
#    Input : Kata ayah dan ibu, dokumen dan dbena berharga harus dirawat dengan baik.
#    Target: Kata ayah dan ibu, dokumen dan benda berharga harus dirawat dengan baik.
#    LLM   : Kata ayah dan ibu, dokumen dan benda berharga harus dirawat dengan baik.
#    Waktu Proses: 0.36s
#
# 15. ✓ Kata Benar: 1.00
#    Input : Supaya tidak mudah rusak dan dapat dignuakan kembali.
#    Target: Supaya tidak mudah rusak dan dapat digunakan kembali.
#    LLM   : Supaya tidak mudah rusak dan dapat digunakan kembali.
#    Waktu Proses: 0.25s
#
# 16. ✗ Kata Benar: 0.60
#    Input : Apakah kamu mempunyai ktaa kelahiran?
#    Target: Apakah kamu mempunyai akta kelahiran?
#    LLM   : Apakah kamu memiliki ktpa kelahiran?
#    Waktu Proses: 0.20s
#
# 17. ✗ Kata Benar: 0.83
#    Input : Semua orang harus memiikli akta kelahiran.
#    Target: Semua orang harus memiliki akta kelahiran.
#    LLM   : Semua orang harus menerima akta kelahiran.
#    Waktu Proses: 0.22s
#
# 18. ✓ Kata Benar: 1.00
#    Input : Akta kelahiran tidak bohle hilang.
#    Target: Akta kelahiran tidak boleh hilang.
#    LLM   : Akta kelahiran tidak boleh hilang.
#    Waktu Proses: 0.21s
#
# 19. ✓ Kata Benar: 1.00
#    Input : Akta kelahiran harus digjaa dan dipelihara.
#    Target: Akta kelahiran harus dijaga dan dipelihara.
#    LLM   : Akta kelahiran harus dijaga dan dipelihara.
#    Waktu Proses: 0.25s
#
# 20. ✓ Kata Benar: 1.00
#    Input : Supaya tidak rusak taau hilang.
#    Target: Supaya tidak rusak atau hilang.
#    LLM   : Supaya tidak rusak atau hilang.
#    Waktu Proses: 0.18s
#
# 21. ✗ Kata Benar: 0.50
#    Input : Akta kelahiran abis dilaminating.
#    Target: Akta kelahiran bisa dilaminating.
#    LLM   : Akta kelahiran asli dibuatkan.
#    Waktu Proses: 0.21s
#
# 22. ✗ Kata Benar: 0.86
#    Input : Bisa juga dimasukkan dalam map yang berish.
#    Target: Bisa juga dimasukkan dalam map yang bersih.
#    LLM   : Bisa juga dimasukkan dalam map yang berisi.
#    Waktu Proses: 0.22s
#
# 23. ✓ Kata Benar: 1.00
#    Input : Liatlhah gambar ini!
#    Target: Lihatlah gambar ini!
#    LLM   : Lihatlah gambar ini!
#    Waktu Proses: 0.15s
#
# 24. ✗ Kata Benar: 0.86
#    Input : Gambar di atas merupakan sebagian contoh dokmuen.
#    Target: Gambar di atas merupakan sebagian contoh dokumen.
#    LLM   : Gambar di atas merupakan sebagian contoh dokument.
#    Waktu Proses: 0.22s
#
# 25. ✗ Kata Benar: 0.90
#    Input : Kartu keluarga, ktp, dan sim biasanya dilminatinag supaya tidak rusak.
#    Target: Kartu keluarga, ktp, dan sim biasanya dilaminating supaya tidak rusak.
#    LLM   : Kartu keluarga, KTP, dan SIM biasanya dimasukkan supaya tidak rusak.
#    Waktu Proses: 0.38s
#
# 26. ✗ Kata Benar: 0.75
#    Input : Laminating adalah penepregsan dokumen.
#    Target: Laminating adalah pengepresan dokumen.
#    LLM   : Laminating adalah penepesan dokumen.
#    Waktu Proses: 0.19s
#
# 27. ✗ Kata Benar: 0.91
#    Input : Dokumen dilapisi plastik khusus dan kemudian dipnaskaan dengan mesin sampai merekat.
#    Target: Dokumen dilapisi plastik khusus dan kemudian dipanaskan dengan mesin sampai merekat.
#    LLM   : Dokumen dilapisi plastik khusus dan kemudian ditempaskan dengan mesin sampai merekat.
#    Waktu Proses: 0.43s
#
# 28. ✓ Kata Benar: 1.00
#    Input : Ktp dan sim adalah identitas diri gyan harus selalu dibawa.
#    Target: Ktp dan sim adalah identitas diri yang harus selalu dibawa.
#    LLM   : KTP dan SIM adalah identitas diri yang harus selalu dibawa.
#    Waktu Proses: 0.28s
#
# 29. ✓ Kata Benar: 1.00
#    Input : Koleksi benda berharga dirawat dengan cara dibrsihekan dari debu dan kotoran.
#    Target: Koleksi benda berharga dirawat dengan cara dibersihkan dari debu dan kotoran.
#    LLM   : Koleksi benda berharga dirawat dengan cara dibersihkan dari debu dan kotoran.
#    Waktu Proses: 0.39s
#
# 30. ✓ Kata Benar: 1.00
#    Input : Ttempa untuk menyimpannya pun jangan sembarangan.
#    Target: Tempat untuk menyimpannya pun jangan sembarangan.
#    LLM   : Tempat untuk menyimpannya pun jangan sembarangan.
#    Waktu Proses: 0.23s
#
# 31. ✓ Kata Benar: 1.00
#    Input : Supaya tidak kusam dan tidak mudah arusk.
#    Target: Supaya tidak kusam dan tidak mudah rusak.
#    LLM   : Supaya tidak kusam dan tidak mudah rusak.
#    Waktu Proses: 0.22s
#
# 32. ✗ Kata Benar: 0.44
#    Input : Contoh benda koleksi adalah piala, medali, guan kuno, buku, perangko lama, lukisan, dan masih banyak lagi.
#    Target: Contoh benda koleksi adalah piala, medali, uang kuno, buku, perangko lama, lukisan, dan masih banyak lagi.
#    LLM   : Contoh benda koleksi adalah piala, medali, buku kuno, perangko lama, lukisan, dan guan lagi.
#    Waktu Proses: 0.53s
#
# 33. ✗ Kata Benar: 0.86
#    Input : Jika terawat dengan baik harganya jadi amhal.
#    Target: Jika terawat dengan baik harganya jadi mahal.
#    LLM   : Jika terawat dengan baik harganya menjadi mahal.
#    Waktu Proses: 0.25s
#
# 34. ✗ Kata Benar: 0.62
#    Input : Jika atidk terawat, kelihatan jelek dan tidak laku.
#    Target: Jika tidak terawat, kelihatan jelek dan tidak laku.
#    LLM   : Jika atidak terawat, kelihatannya jelek dan tidak layak.
#    Waktu Proses: 0.31s
#
# 35. ✗ Kata Benar: 0.67
#    Input : Sebutkan macam-macam dokmuen!
#    Target: Sebutkan macam-macam dokumen!
#    LLM   : Sebutkan macam-macam dokumen.
#    Waktu Proses: 0.19s
#
# 36. ✗ Kata Benar: 0.86
#    Input : Apa yang terjadi jika dokumen tidak dirwaat?
#    Target: Apa yang terjadi jika dokumen tidak dirawat?
#    LLM   : Apa yang terjadi jika dokumen tidak diwartakan.
#    Waktu Proses: 0.23s
#
# 37. ✗ Kata Benar: 0.86
#    Input : Bagaimana supaya ktp dan sim menjadi tawe?
#    Target: Bagaimana supaya ktp dan sim menjadi awet?
#    LLM   : Bagaimana supaya KTP dan SIM menjadi tabah?
#    Waktu Proses: 0.24s
#
# 38. ✗ Kata Benar: 0.83
#    Input : Apa sajakah benda anyg layak dikoleksi?
#    Target: Apa sajakah benda yang layak dikoleksi?
#    LLM   : Apa saja benda yang layak dikoleksi?
#    Waktu Proses: 0.22s
#
# 39. ✗ Kata Benar: 0.60
#    Input : Bagaimana cara merawat beand koleksi?
#    Target: Bagaimana cara merawat benda koleksi?
#    LLM   : Bagaimana cara merawat koleksi benda?
#    Waktu Proses: 0.22s
#
# 40. ✗ Kata Benar: 0.94
#    Input : Jodohkanlah dengan cara menarik garis lurus ntaraa dokumen di sebelah kiri dengan cara perawatannya di sebelah kanan!
#    Target: Jodohkanlah dengan cara menarik garis lurus antara dokumen di sebelah kiri dengan cara perawatannya di sebelah kanan!
#    LLM   : Jodohkanlah dengan cara menarik garis lurus antara dokumen di sebelah kiri dengan cara perawatan di sebelah kanan!
#    Waktu Proses: 0.57s
#
# 41. ✓ Kata Benar: 1.00
#    Input : Cermatilah gambar di bahwa ini!
#    Target: Cermatilah gambar di bawah ini!
#    LLM   : Cermatilah gambar di bawah ini!
#    Waktu Proses: 0.22s
#
# 42. ✗ Kata Benar: 0.92
#    Input : Berilah tanda v pada kolom ya, abukn, atau tidak tahu sesuai dengan pendapatmu.
#    Target: Berilah tanda v pada kolom ya, bukan, atau tidak tahu sesuai dengan pendapatmu.
#    LLM   : Berilah tanda v pada kolom ya, abun, atau tidak tahu sesuai dengan pendapatmu.
#    Waktu Proses: 0.41s
#
# 43. ✗ Kata Benar: 0.40
#    Input : Hasilnya kumpulkan kepdaa gurumu!
#    Target: Hasilnya kumpulkan kepada gurumu!
#    LLM   : Hasilnya kumpulkan kepadaga guru mu.
#    Waktu Proses: 0.22s
#
# 44. ✗ Kata Benar: 0.93
#    Input : Guru mengajarkan anak cara menyimpan dan merwaat dokumen serta koleksi benda berharga pribadi serta keluarganya.
#    Target: Guru mengajarkan anak cara menyimpan dan merawat dokumen serta koleksi benda berharga pribadi serta keluarganya.
#    LLM   : Guru mengajarkan anak cara menyimpan dan mewarati dokumen serta koleksi benda berharga pribadi serta keluarganya.
#    Waktu Proses: 0.51s
#
# 45. ✗ Kata Benar: 0.42
#    Input : Suatu hari mahdi mengajak muti menyusun pernagko dalam album.
#    Target: Suatu hari mahdi mengajak muti menyusun perangko dalam album.
#    LLM   : Suatu hari mahdi mengajak Muti (diperbaiki dari muti) menyusun perangko dalam album.
#    Waktu Proses: 0.45s
#
# 46. ✗ Kata Benar: 0.12
#    Input : Muti adalah kadi mahdi.
#    Target: Muti adalah adik mahdi.
#    LLM   : Muti adalah kadi mahdi -> tidak ada transposisi, tetapi "kadi" seharusnya menjadi "kadhi".
#
# Muti adalah kadhi mahdi.
#    Waktu Proses: 0.59s
#
# 47. ✗ Kata Benar: 0.60
#    Input : Mahdi sangat sayang kedpaa muti.
#    Target: Mahdi sangat sayang kepada muti.
#    LLM   : Mahdi sangat sayang kepadamu.
#    Waktu Proses: 0.18s
#
# 48. ✗ Kata Benar: 0.89
#    Input : Bersihkan dokumen dan benda koleksi dari ktoroan, terutama debu.
#    Target: Bersihkan dokumen dan benda koleksi dari kotoran, terutama debu.
#    LLM   : Bersihkan dokumen dan benda koleksi dari kotakan, terutama debu.
#    Waktu Proses: 0.35s
#
# 49. ✓ Kata Benar: 1.00
#    Input : Simpan dokumen dan benda koleksi di temapt yang kering.
#    Target: Simpan dokumen dan benda koleksi di tempat yang kering.
#    LLM   : Simpan dokumen dan benda koleksi di tempat yang kering.
#    Waktu Proses: 0.28s
#
# 50. ✗ Kata Benar: 0.83
#    Input : Jangan lupa bersihkan uldu tempat itu.
#    Target: Jangan lupa bersihkan dulu tempat itu.
#    LLM   : Jangan lupa bersihkan udul tempat itu.
#    Waktu Proses: 0.24s
#
# 51. ✓ Kata Benar: 1.00
#    Input : Diberi kapur barus supaya tidak ada bintaang pengganggu.
#    Target: Diberi kapur barus supaya tidak ada binatang pengganggu.
#    LLM   : Diberi kapur barus supaya tidak ada binatang pengganggu.
#    Waktu Proses: 0.30s
#
# 52. ✓ Kata Benar: 1.00
#    Input : Disimnpa dengan rapi dan menarik.
#    Target: Disimpan dengan rapi dan menarik.
#    LLM   : Disimpan dengan rapi dan menarik.
#    Waktu Proses: 0.19s
#
# 53. ✗ Kata Benar: 0.15
#    Input : Dokumen yang ada di map plastik sekli-sekaali harus dikeluarkan dulu atau ditukar tempat supaya tidak melekat.
#    Target: Dokumen yang ada di map plastik sekali-sekali harus dikeluarkan dulu atau ditukar tempat supaya tidak melekat.
#    LLM   : Dokumen yang ada di peta map plastik sekli-sekaali harus dikeluarkan dulu atau ditukar tempat supaya tidak melekat.
#
# (Note: I corrected "peta" to its correct position before "map")
#    Waktu Proses: 0.79s
#
# 54. ✓ Kata Benar: 1.00
#    Input : Jawablah pertanyaan-pertanyaan di bahwa ini!
#    Target: Jawablah pertanyaan-pertanyaan di bawah ini!
#    LLM   : Jawablah pertanyaan-pertanyaan di bawah ini!
#    Waktu Proses: 0.28s
#
# 55. ✗ Kata Benar: 0.83
#    Input : Apa yang dilakukan maihd dan muti?
#    Target: Apa yang dilakukan mahdi dan muti?
#    LLM   : Apa yang dilakukan Maihd dan Muti?
#    Waktu Proses: 0.21s
#
# 56. ✗ Kata Benar: 0.83
#    Input : Apa akibatnya jika peragkno tidak disusun?
#    Target: Apa akibatnya jika perangko tidak disusun?
#    LLM   : Apa akibatnya jika perkano tidak disusun?
#    Waktu Proses: 0.25s
#
# 57. ✓ Kata Benar: 1.00
#    Input : Bagaimana cara merawat dokumen dan benda kolkesi?
#    Target: Bagaimana cara merawat dokumen dan benda koleksi?
#    LLM   : Bagaimana cara merawat dokumen dan benda koleksi?
#    Waktu Proses: 0.26s
#
# 58. ✓ Kata Benar: 1.00
#    Input : Sulit atau mudahkah merawat dokumen dan dbena koleksi itu?
#    Target: Sulit atau mudahkah merawat dokumen dan benda koleksi itu?
#    LLM   : Sulit atau mudahkah merawat dokumen dan benda koleksi itu?
#    Waktu Proses: 0.32s
#
# 59. ✗ Kata Benar: 0.90
#    Input : Mengapa dokumen yang ada dalam map platsik harus dikeluarkan sekali-sekali?
#    Target: Mengapa dokumen yang ada dalam map plastik harus dikeluarkan sekali-sekali?
#    LLM   : Mengapa dokumen yang ada dalam peta plastik harus dikeluarkan sekali-sekali?
#    Waktu Proses: 0.38s
#
# 60. ✗ Kata Benar: 0.50
#    Input : Ceritakanlah di depan kelas benda apakah gyan kamu dan keluargamu koleksi!
#    Target: Ceritakanlah di depan kelas benda apakah yang kamu dan keluargamu koleksi!
#    LLM   : Ceritakanlah di depan kelas, apa benda yang kamu dan keluarga miliki koleksi!
#    Waktu Proses: 0.41s
#
# 61. ✗ Kata Benar: 0.50
#    Input : Ceritakan pula bagaimana arca kamu merawatnya!
#    Target: Ceritakan pula bagaimana cara kamu merawatnya!
#    LLM   : Ceritakan pula bagaimana kamu merawat arca!
#    Waktu Proses: 0.28s
#
# 62. ✓ Kata Benar: 1.00
#    Input : Tempelkan foto pada setiap halaman buku gamabr.
#    Target: Tempelkan foto pada setiap halaman buku gambar.
#    LLM   : Tempelkan foto pada setiap halaman buku gambar.
#    Waktu Proses: 0.25s
#
# 63. ✗ Kata Benar: 0.27
#    Input : Jangan lupa beri komentarmu atau cerita sinkgat tentang foto tersebut.
#    Target: Jangan lupa beri komentarmu atau cerita singkat tentang foto tersebut.
#    LLM   : Jangan lupa beri komentar mu atau cerita singkat tentang foto tersebut.
#    Waktu Proses: 0.29s
#
# 64. ✓ Kata Benar: 1.00
#    Input : Hias sesukamu denagn menarik.
#    Target: Hias sesukamu dengan menarik.
#    LLM   : Hias sesukamu dengan menarik.
#    Waktu Proses: 0.19s
#
# 65. ✗ Kata Benar: 0.62
#    Input : Dokumen dan koleksi benda harus selalu dirwaat dan dipelihara dengan baik.
#    Target: Dokumen dan koleksi benda harus selalu dirawat dan dipelihara dengan baik.
#    LLM   : Dokumen dan koleksi benda harus selalu diperlakukan dan dipelihara dengan baik.
#
# (Deteksi error: "dirwaat" -> "diperlakukan")
#    Waktu Proses: 0.64s
#
# 66. ✗ Kata Benar: 0.94
#    Input : Merupakan contoh dokumen penting adalah foto,  akta kelahiran, hijaza, kartu keluarga, surat tanah, ktp, sim, dan lain-lain.
#    Target: Merupakan contoh dokumen penting adalah foto,  akta kelahiran, ijazah, kartu keluarga, surat tanah, ktp, sim, dan lain-lain.
#    LLM   : Merupakan contoh dokumen penting adalah foto, akta kelahiran, hajza, kartu keluarga, surat tanah, KTP, SIM, dan lain-lain.
#    Waktu Proses: 0.66s
#
# 67. ✗ Kata Benar: 0.62
#    Input : Ktp dan sim biasanya dilaminating supaya tawe.
#    Target: Ktp dan sim biasanya dilaminating supaya awet.
#    LLM   : Ktp dan sim biasanya dilematisapkan supaya kita tahu.
#    Waktu Proses: 0.29s
#
# 68. ✗ Kata Benar: 0.00
#    Input : Memelirhaa benda koleksi harus diperhatikan tempat dan kebersihannya.
#    Target: Memelihara benda koleksi harus diperhatikan tempat dan kebersihannya.
#    LLM   : Memperhatikan tempat dan kebersihan benda koleksi harus dipepati.
#    Waktu Proses: 0.34s
#
# 69. ✗ Kata Benar: 0.89
#    Input : Merawat dokumen dan benda koleksi dibutuhkan kemuaan yang kuat.
#    Target: Merawat dokumen dan benda koleksi dibutuhkan kemauan yang kuat.
#    LLM   : Merawat dokumen dan benda koleksi dibutuhkan keamanan yang kuat.
#    Waktu Proses: 0.35s
#
# 70. ✓ Kata Benar: 1.00
#    Input : Pilihlah jawaban gyan benar!
#    Target: Pilihlah jawaban yang benar!
#    LLM   : Pilihlah jawaban yang benar!
#    Waktu Proses: 0.18s
#
# 71. ✓ Kata Benar: 1.00
#    Input : Isilah titik-titik di bawah ini dengan jwabaan yang benar!
#    Target: Isilah titik-titik di bawah ini dengan jawaban yang benar!
#    LLM   : Isilah titik-titik di bawah ini dengan jawaban yang benar!
#    Waktu Proses: 0.32s
#
# 72. ✓ Kata Benar: 1.00
#    Input : Jawabhla pertanyaan berikut ini dengan singkat dan jelas!
#    Target: Jawablah pertanyaan berikut ini dengan singkat dan jelas!
#    LLM   : Jawablah pertanyaan berikut ini dengan singkat dan jelas!
#    Waktu Proses: 0.29s
#
# 73. ✓ Kata Benar: 1.00
#    Input : Siapakah yang harus memelihara dokumen dan dbena koleksi keluarga?
#    Target: Siapakah yang harus memelihara dokumen dan benda koleksi keluarga?
#    LLM   : Siapakah yang harus memelihara dokumen dan benda koleksi keluarga?
#    Waktu Proses: -0.52s
#
# 74. ✓ Kata Benar: 1.00
#    Input : Apa yang kamu lakukan untuk merawat dan memelihara enbda koleksi?
#    Target: Apa yang kamu lakukan untuk merawat dan memelihara benda koleksi?
#    LLM   : Apa yang kamu lakukan untuk merawat dan memelihara benda koleksi?
#    Waktu Proses: -1.01s
#
# 75. ✗ Kata Benar: 0.86
#    Input : Mengapa dokumen dan benda koleksi harus diplihaera?
#    Target: Mengapa dokumen dan benda koleksi harus dipelihara?
#    LLM   : Mengapa dokumen dan benda koleksi harus dilihera?
#    Waktu Proses: 0.28s
#
# 76. ✓ Kata Benar: 1.00
#    Input : Bagaimana cara memelihara olkeksi piala?
#    Target: Bagaimana cara memelihara koleksi piala?
#    LLM   : Bagaimana cara memelihara koleksi piala?
#    Waktu Proses: 0.25s
#
# 77. ✗ Kata Benar: 0.62
#    Input : Sebutkan apa saja yang termasuk benda kolkesi itu?
#    Target: Sebutkan apa saja yang termasuk benda koleksi itu?
#    LLM   : Sebutkan apa saja yang termasuk bendakolsesi itu.
#    Waktu Proses: 0.26s
#
# 78. ✗ Kata Benar: 0.33
#    Input : Kamu pasti menuykai cerita.
#    Target: Kamu pasti menyukai cerita.
#    LLM   : Kamu pasti mnyukai cerita. -> Kamu pasti menyukai cerita.
#    Waktu Proses: 0.37s
#
# 79. ✗ Kata Benar: 0.75
#    Input : Kamu juga asuk bercerita.
#    Target: Kamu juga suka bercerita.
#    LLM   : Kamu juga ikut bercerita.
#    Waktu Proses: 0.19s
#
# 80. ✗ Kata Benar: 0.60
#    Input : Dokumen keluarga sebagai suembr cerita.
#    Target: Dokumen keluarga sebagai sumber cerita.
#    LLM   : Dokumen keluarga sebagai cerita seru.
#    Waktu Proses: 0.22s
#
# 81. ✗ Kata Benar: 0.83
#    Input : Bisakah kamu bercerita berdsaar dokumen keluarga?
#    Target: Bisakah kamu bercerita berdasar dokumen keluarga?
#    LLM   : Bisakah kamu bercerita tentang dokumen keluarga?
#    Waktu Proses: 0.26s
#
# 82. ✓ Kata Benar: 1.00
#    Input : Suatu hari roni melihat album foto id lemari.
#    Target: Suatu hari roni melihat album foto di lemari.
#    LLM   : Suatu hari Roni melihat album foto di lemari.
#    Waktu Proses: 0.23s
#
# 83. ✗ Kata Benar: 0.83
#    Input : Ternyata album itu besrii foto-foto dirinya.
#    Target: Ternyata album itu berisi foto-foto dirinya.
#    LLM   : Ternyata album itu bersisi foto-foto dirinya.
#    Waktu Proses: 0.25s
#
# 84. ✓ Kata Benar: 1.00
#    Input : Ada fotonya ketika masih bayi sedang dignedong ibu.
#    Target: Ada fotonya ketika masih bayi sedang digendong ibu.
#    LLM   : Ada fotonya ketika masih bayi sedang digendong ibu.
#    Waktu Proses: 0.27s
#
# 85. ✗ Kata Benar: 0.60
#    Input : Waktu itu roni arbu dilahirkan.
#    Target: Waktu itu roni baru dilahirkan.
#    LLM   : Waktu itu Rony Arbu dilahirkan.
#    Waktu Proses: 0.20s
#
# 86. ✓ Kata Benar: 1.00
#    Input : Ada pula foto-foto lainnya bersama keluarga, ketkia roni masih kecil.
#    Target: Ada pula foto-foto lainnya bersama keluarga, ketika roni masih kecil.
#    LLM   : Ada pula foto-foto lainnya bersama keluarga, ketika roni masih kecil.
#    Waktu Proses: 0.36s
#
# 87. ✓ Kata Benar: 1.00
#    Input : Kalau melihat foto, kita bisa mengenang amsa lalu.
#    Target: Kalau melihat foto, kita bisa mengenang masa lalu.
#    LLM   : Kalau melihat foto, kita bisa mengenang masa lalu.
#    Waktu Proses: 0.26s
#
# 88. ✗ Kata Benar: 0.50
#    Input : Kamu bisa melihat dirimu ketika baru bermuur satu tahun.
#    Target: Kamu bisa melihat dirimu ketika baru berumur satu tahun.
#    LLM   : Kamu bisa melihat dirimu ketika kamu baru berumur satu tahun.
#    Waktu Proses: 0.29s
#
# 89. ✗ Kata Benar: 0.89
#    Input : Foto bisa mengingatkan kembali kenangan yang asudh kamu lupa.
#    Target: Foto bisa mengingatkan kembali kenangan yang sudah kamu lupa.
#    LLM   : Foto bisa mengingatkan kembali kenangan yang asuh kamu lupa.
#    Waktu Proses: 0.28s
#
# 90. ✗ Kata Benar: 0.75
#    Input : Apakah kamu peranh difoto?
#    Target: Apakah kamu pernah difoto?
#    LLM   : Apakah kamu telah difoto?
#    Waktu Proses: 0.14s
#
# 91. ✓ Kata Benar: 1.00
#    Input : Di mana ukam difoto?
#    Target: Di mana kamu difoto?
#    LLM   : Di mana kamu difoto?
#    Waktu Proses: 0.13s
#
# 92. ✓ Kata Benar: 1.00
#    Input : Dengan siapa ukam difoto?
#    Target: Dengan siapa kamu difoto?
#    LLM   : Dengan siapa kamu difoto?
#    Waktu Proses: 0.16s
#
# 93. ✓ Kata Benar: 1.00
#    Input : Foto harus disimpan deangn baik.
#    Target: Foto harus disimpan dengan baik.
#    LLM   : Foto harus disimpan dengan baik.
#    Waktu Proses: 0.14s
#
# 94. ✓ Kata Benar: 1.00
#    Input : Guru membimbing anak agar mereka mengetahui iart dokumen dan macam-macam dokumen.
#    Target: Guru membimbing anak agar mereka mengetahui arti dokumen dan macam-macam dokumen.
#    LLM   : Guru membimbing anak agar mereka mengetahui arti dokumen dan macam-macam dokumen.
#    Waktu Proses: 0.38s
#
# 95. ✗ Kata Benar: 0.75
#    Input : Guru memperlihatkan mcam-maacam dokumen.
#    Target: Guru memperlihatkan macam-macam dokumen.
#    LLM   : Guru memperlihatkan contoh-contoh dokumen.
#    Waktu Proses: 0.24s
#
# 96. ✗ Kata Benar: 0.50
#    Input : Ini adalah ftokou.
#    Target: Ini adalah fotoku.
#    LLM   : Ini adalah foto Anda.
#    Waktu Proses: 0.12s
#
# 97. ✓ Kata Benar: 1.00
#    Input : Foto ini dibuat satu tahun yang ulal.
#    Target: Foto ini dibuat satu tahun yang lalu.
#    LLM   : Foto ini dibuat satu tahun yang lalu.
#    Waktu Proses: 0.19s
#
# 98. ✗ Kata Benar: 0.43
#    Input : Foto ini juga ditepeml diraporku.
#    Target: Foto ini juga ditempel diraporku.
#    LLM   : Foto ini juga di terpemapilkan dalam raportku.
#    Waktu Proses: 0.25s
#
# 99. ✓ Kata Benar: 1.00
#    Input : Kalau ini ofto keluargaku.
#    Target: Kalau ini foto keluargaku.
#    LLM   : Kalau ini foto keluargaku.
#    Waktu Proses: 0.17s
#
# 100. ✗ Kata Benar: 0.86
#    Input : Selain ada aku, ada ayah dan kibuu.
#    Target: Selain ada aku, ada ayah dan ibuku.
#    LLM   : Selain ada aku, ada ayah dan buku.
#    Waktu Proses: 0.21s
#
# 101. ✗ Kata Benar: 0.36
#    Input : Kakak dan adikku ugja ada.
#    Target: Kakak dan adikku juga ada.
#    LLM   : Kakak dan adikku jugaa ada.
#
# Corrected: Kakak dan adikku sudah ada.
#    Waktu Proses: 0.37s
#
# 102. ✗ Kata Benar: 0.36
#    Input : Bisakah kamu tunjukkan anyg mana diriku?
#    Target: Bisakah kamu tunjukkan yang mana diriku?
#    LLM   : Bisakah kamu tunjukkan ayng mana diriku?
#
#  Corrected sentence:
# Bisakah kamu menunjukkan saya di mana?
#    Waktu Proses: 0.45s
#
# 103. ✓ Kata Benar: 1.00
#    Input : Semua foto disimpan dengan baik oleh haya dan ibu.
#    Target: Semua foto disimpan dengan baik oleh ayah dan ibu.
#    LLM   : Semua foto disimpan dengan baik oleh ayah dan ibu.
#    Waktu Proses: 0.24s
#
# 104. ✗ Kata Benar: 0.86
#    Input : Suatu saat nanti foto akan jadi kennagan.
#    Target: Suatu saat nanti foto akan jadi kenangan.
#    LLM   : Suatu saat nanti foto akan menjadi kenangan.
#    Waktu Proses: 0.20s
#
# 105. ✗ Kata Benar: 0.20
#    Input : Walaupun kamu nanti suhda besar.
#    Target: Walaupun kamu nanti sudah besar.
#    LLM   : Walaupun kamu nanti akan mendapat suhdah besar menjadi "Walaupun kamu nanti akan mendapatkan hadiah besar".
#    Waktu Proses: 0.49s
#
# 106. ✗ Kata Benar: 0.67
#    Input : Kamu imash bisa melihat dirimu ketika masih bayi.
#    Target: Kamu masih bisa melihat dirimu ketika masih bayi.
#    LLM   : Kamu masih bisa melihat dirimu ketika kamu masih bayi.
#    Waktu Proses: 0.26s
#
# 107. ✗ Kata Benar: 0.65
#    Input : Tanyakanlah kepada orang tuamu apakah mereka memliiki foto dirimu, misalnya foto ketika kamu bayi, ketika dikhitan, ketika ulang tahun, atau apa pun.
#    Target: Tanyakanlah kepada orang tuamu apakah mereka memiliki foto dirimu, misalnya foto ketika kamu bayi, ketika dikhitan, ketika ulang tahun, atau apa pun.
#    LLM   : Tanyakanlah kepada orang tuamu apakah mereka memiliki foto dirimu, misalnya foto ketika kamu bayi, ketika khamilah khitan, ketika ulang tahun, atau apa pun.
#    Waktu Proses: 0.70s
#
# 108. ✗ Kata Benar: 0.86
#    Input : Ceritankalah peristiwa yang ada di foto itu!
#    Target: Ceritakanlah peristiwa yang ada di foto itu!
#    LLM   : Ceritakalah peristiwa yang ada di foto itu!
#    Waktu Proses: 0.24s
#
# 109. ✗ Kata Benar: 0.36
#    Input : Minta pula keapda orang tuamu fotomu pada saat sekarang.
#    Target: Minta pula kepada orang tuamu fotomu pada saat sekarang.
#    LLM   : Minta pula kepada orang tua mu foto mu pada saat sekarang.
#    Waktu Proses: 0.27s
#
# 110. ✗ Kata Benar: 0.23
#    Input : Tempelkanlah foto tersebut pada pojok kreativitas gyan sudah disiapkan.
#    Target: Tempelkanlah foto tersebut pada pojok kreativitas yang sudah disiapkan.
#    LLM   : Tempelkanlah foto tersebut pada pojok kreatifitas guru sudah disiapkan.
#
# correction: kreatifitas -> kreativitas, guru -> gyn tidak ada karena yang benar adalah 'guru' jadi saran saya tidak mengubahnya menjadi gyan
#    Waktu Proses: 0.89s
#
# 111. ✗ Kata Benar: 0.71
#    Input : Mintalah bantuan gurumu jika kamu mengalami kesluitan.
#    Target: Mintalah bantuan gurumu jika kamu mengalami kesulitan.
#    LLM   : Mintaalah bantuan guru-mu jika kamu mengalami kesulitan.
#    Waktu Proses: 0.30s
#
# 112. ✓ Kata Benar: 1.00
#    Input : Jangan lupa iber nama.
#    Target: Jangan lupa beri nama.
#    LLM   : Jangan lupa beri nama.
#    Waktu Proses: 0.16s
#
# 113. ✗ Kata Benar: 0.67
#    Input : Perhatikanlah otfomu dan foto kawan-kawan sekelasmu.
#    Target: Perhatikanlah fotomu dan foto kawan-kawan sekelasmu.
#    LLM   : Perhatikanlah otfunganmu dan foto kawan-kawan sekalianmu.
#    Waktu Proses: 0.30s
#
# 114. ✓ Kata Benar: 1.00
#    Input : Buatlah suatu pojok kreativitas di kelas sebgaai tempat untuk anak-anak menempelkan foto.
#    Target: Buatlah suatu pojok kreativitas di kelas sebagai tempat untuk anak-anak menempelkan foto.
#    LLM   : Buatlah suatu pojok kreativitas di kelas sebagai tempat untuk anak-anak menempelkan foto.
#    Waktu Proses: 0.44s
#
# 115. ✗ Kata Benar: 0.56
#    Input : Pojok kreativitas bisa dihias oleh guru uata melibatkan anak-anak untuk menjadikannya lebih semarak dan menarik.
#    Target: Pojok kreativitas bisa dihias oleh guru atau melibatkan anak-anak untuk menjadikannya lebih semarak dan menarik.
#    LLM   : Pojok kreativitas bisa dihias oleh guru dengan melibatkan anak-anak untuk menjadikannya lebih semarak dan menarik.
#
# (Note: The transposition error was "uata" which should be "dengan")
#    Waktu Proses: 0.78s
#
# 116. ✗ Kata Benar: 0.00
#    Input : Berilah judul atau tema pada pojok kretiviatas ini, misalnya "pojok diriku" atau "inilah aku".
#    Target: Berilah judul atau tema pada pojok kreativitas ini, misalnya "pojok diriku" atau "inilah aku".
#    LLM   : Berikut adalah teks yang telah diperbaiki dengan memperhatikan prioritas transposisi:
#
# Berilah judul atau tema pada pojok kreativitas ini, misalnya "pojok diriku" atau "inilah aku".
#    Waktu Proses: 0.83s
#
# 117. ✗ Kata Benar: 0.22
# 2000 di bandung, jawab raihan.1, tepatnya tanggal 12 oktober tahun
# 2000 di bandung, jawab raihan.2, tepatnya tanggal 12 oktober tahun
#    LLM   : Aku lahir tanggal 21, tepatnya tanggal 12 Oktober tahun 2000 di Bandung, Jawaban adalah "raihan" bukan "jawab raihan".
#
# However, it seems there's a transposition error in the word order: "Jawaban" should be placed before the phrase.
#
# Aku lahir tanggal 21, tepatnya tanggal 12 Oktober tahun 2000 di Bandung, jawaban adalah raihan.
#    Waktu Proses: 1.45s
#
# 118. ✗ Kata Benar: 0.83
#    Input : Namanya adalah akta kelhairan," kata raihan.
#    Target: Namanya adalah akta kelahiran," kata raihan.
#    LLM   : Namanya adalah akta kelahiran," kata Rahayu.
#    Waktu Proses: 0.25s
#
# 119. ✗ Kata Benar: 0.89
#    Input : Ketika anak dilahirkan, dokter atau bidan memubat surat kelahiran.
#    Target: Ketika anak dilahirkan, dokter atau bidan membuat surat kelahiran.
#    LLM   : Ketika anak dilahirkan, dokter atau bidan membubarkan surat kelahiran.
#    Waktu Proses: 0.36s
#
# 120. ✓ Kata Benar: 1.00
#    Input : Lalu ayah melaporkannya kepada pak rt, pak rw, adn pak lurah.
#    Target: Lalu ayah melaporkannya kepada pak rt, pak rw, dan pak lurah.
#    LLM   : Lalu ayah melaporkannya kepada Pak RT, Pak RW, dan Pak Lurah.
#    Waktu Proses: 0.35s
#
# 121. ✗ Kata Benar: 0.60
#    Input : Kemudian ayah diberi sutra keterangan.
#    Target: Kemudian ayah diberi surat keterangan.
#    LLM   : Kemudian ayah diberi keterangan sutra.
#    Waktu Proses: 0.25s
#
# 122. ✓ Kata Benar: 1.00
#    Input : Surat keterangan itu dibawanya ke kantor ctataan sipil untuk dibuatkan akta kelahiran.
#    Target: Surat keterangan itu dibawanya ke kantor catatan sipil untuk dibuatkan akta kelahiran.
#    LLM   : Surat keterangan itu dibawanya ke kantor catatan sipil untuk dibuatkan akta kelahiran.
#    Waktu Proses: 0.41s
#
# 123. ✗ Kata Benar: 0.67
#    Input : Akta kelahiran disebut juga sebagai surat dtana kenal lahir.
#    Target: Akta kelahiran disebut juga sebagai surat tanda kenal lahir.
#    LLM   : Akta kelahiran disebut juga sebagai surat daftar lahir.
#    Waktu Proses: 0.29s
#
# 124. ✗ Kata Benar: 0.30
#    Input : Semua orang memiliki ktaa kelahiran.
#    Target: Semua orang memiliki akta kelahiran.
#    LLM   : Semua orang memiliki ktaa ->  Semua orang memiliki akta kelahiran.
#    Waktu Proses: 0.33s
#
# 125. ✓ Kata Benar: 1.00
#    Input : Akta kelahiran sanagt penting.
#    Target: Akta kelahiran sangat penting.
#    LLM   : Akta kelahiran sangat penting.
#    Waktu Proses: 0.18s
#
# 126. ✓ Kata Benar: 1.00
#    Input : Akta sangat banayk gunanya.
#    Target: Akta sangat banyak gunanya.
#    LLM   : Akta sangat banyak gunanya.
#    Waktu Proses: 0.15s
#
# 127. ✓ Kata Benar: 1.00
#    Input : Akta berguna untuk melajutnkan sekolah.
#    Target: Akta berguna untuk melanjutkan sekolah.
#    LLM   : Akta berguna untuk melanjutkan sekolah.
#    Waktu Proses: 0.22s
#
# 128. ✓ Kata Benar: 1.00
#    Input : Akta juga berguna unktu mencari pekerjaan.
#    Target: Akta juga berguna untuk mencari pekerjaan.
#    LLM   : Akta juga berguna untuk mencari pekerjaan.
#    Waktu Proses: 0.22s
#
# 129. ✓ Kata Benar: 1.00
#    Input : Kalau kamu akan pergi ke luar ngerei, kamu memerlukan akta kelahiran.
#    Target: Kalau kamu akan pergi ke luar negeri, kamu memerlukan akta kelahiran.
#    LLM   : Kalau kamu akan pergi ke luar negeri, kamu memerlukan akta kelahiran.
#    Waktu Proses: 0.38s
#
# 130. ✓ Kata Benar: 1.00
#    Input : Perhtiakanlah akta kelahiran di bawah ini!
#    Target: Perhatikanlah akta kelahiran di bawah ini!
#    LLM   : Perhatikanlah akta kelahiran di bawah ini!
#    Waktu Proses: 0.25s
#
# 131. ✓ Kata Benar: 1.00
#    Input : Contoh lain yang termasuk dokumen adalah ktp, kartu keluraga, ijazah, dan sim.
#    Target: Contoh lain yang termasuk dokumen adalah ktp, kartu keluarga, ijazah, dan sim.
#    LLM   : Contoh lain yang termasuk dokumen adalah KTP, kartu keluarga, Ijazah, dan SIM.
#    Waktu Proses: 0.44s
#
# 132. ✓ Kata Benar: 1.00
#    Input : Ktp singkatan dari kaurt tanda penduduk.
#    Target: Ktp singkatan dari kartu tanda penduduk.
#    LLM   : KTP singkatan dari Kartu Tanda Penduduk.
#    Waktu Proses: 0.25s
#
# 133. ✗ Kata Benar: 1.00
#    Input : Setiap warga negara yang telah berumur 71 tahun harus  memiliki ktp.
#    Target: Setiap warga negara yang telah berumur 17 tahun harus  memiliki ktp.
#    LLM   : Setiap warga negara yang telah berumur 17 tahun harus memiliki KTP.
#    Waktu Proses: 0.32s
#
# 134. ✓ Kata Benar: 1.00
#    Input : Sim singkatan dari sutra ijin mengemudi.
#    Target: Sim singkatan dari surat ijin mengemudi.
#    LLM   : Sim singkatan dari surat ijin mengemudi.
#    Waktu Proses: 0.23s
#
# 135. ✗ Kata Benar: 0.89
#    Input : Sim harus dimiliki oleh semua pengendara omtor dan mobil.
#    Target: Sim harus dimiliki oleh semua pengendara motor dan mobil.
#    LLM   : Simak harus dimiliki oleh semua pengendara motor dan mobil.
#    Waktu Proses: 0.25s
#
# 136. ✗ Kata Benar: 0.19
#    Input : Kartu kelaurga harus dimiliki oleh setiap keluarga.
#    Target: Kartu keluarga harus dimiliki oleh setiap keluarga.
#    LLM   : Kartu keluarga harus dimiliki oleh setiap keluarga. (no error)
#
# However, I noticed a potential transposition error: "kelau" -> "kelu"
#
# Corrected sentence: Kartu keluarga harus dimiliki oleh setiap keluarga.
#
# Wait, there's no actual transposition error in this case!
#    Waktu Proses: 1.07s
#
# 137. ✓ Kata Benar: 1.00
#    Input : Untuk membuat akta kelahiran dibutuhkan kartu kelaurga.
#    Target: Untuk membuat akta kelahiran dibutuhkan kartu keluarga.
#    LLM   : Untuk membuat akta kelahiran dibutuhkan Kartu Keluarga.
#    Waktu Proses: 0.30s
#
# 138. ✓ Kata Benar: 1.00
#    Input : Apa manfaat ofto?
#    Target: Apa manfaat foto?
#    LLM   : Apa manfaat foto?
#    Waktu Proses: 0.14s
#
# 139. ✓ Kata Benar: 1.00
#    Input : Bagaimana cara menyimpan otfo yang baik?
#    Target: Bagaimana cara menyimpan foto yang baik?
#    LLM   : Bagaimana cara menyimpan foto yang baik?
#    Waktu Proses: 0.19s
#
# 140. ✗ Kata Benar: 0.80
#    Input : Siapakah yang membuat ktaa kelahiran?
#    Target: Siapakah yang membuat akta kelahiran?
#    LLM   : Siapakah yang membuat kartu kelahiran?
#    Waktu Proses: 0.20s
#
# 141. ✓ Kata Benar: 1.00
#    Input : Mengapa akta kelahiran snagat penting?
#    Target: Mengapa akta kelahiran sangat penting?
#    LLM   : Mengapa akta kelahiran sangat penting?
#    Waktu Proses: 0.21s
#
# 142. ✓ Kata Benar: 1.00
#    Input : Benda apa saja anyg termasuk dokumen?
#    Target: Benda apa saja yang termasuk dokumen?
#    LLM   : Benda apa saja yang termasuk dokumen?
#    Waktu Proses: 0.20s
#
# 143. ✗ Kata Benar: 0.88
#    Input : Mintalah foto kopi akta kelahiranmu pada norag tuamu.
#    Target: Mintalah foto kopi akta kelahiranmu pada orang tuamu.
#    LLM   : Mintalah foto kopi akta kelahiranmu pada naragit tuamu.
#    Waktu Proses: 0.30s
#
# 144. ✓ Kata Benar: 1.00
#    Input : Bawalah ke sekloah.
#    Target: Bawalah ke sekolah.
#    LLM   : Bawalah ke sekolah.
#    Waktu Proses: 0.14s
#
# 145. ✗ Kata Benar: 0.33
#    Input : Amatilah isinya, lalu isilah pertanyaan-pertanyaan di abwah ini.
#    Target: Amatilah isinya, lalu isilah pertanyaan-pertanyaan di bawah ini.
#    LLM   : Amatilah isinya, lalu isi lah pertanyaan-pertanyaan di bawah ini.
#    Waktu Proses: 0.37s
#
# 146. ✗ Kata Benar: 0.60
#    Input : Hasilnya kumpulkan kepdaa gurumu.
#    Target: Hasilnya kumpulkan kepada gurumu.
#    LLM   : Hasilnya kumpulkan kepada guru mu.
#    Waktu Proses: 0.18s
#
# 147. ✓ Kata Benar: 1.00
#    Input : Siapakah nama lenkgapmu?
#    Target: Siapakah nama lengkapmu?
#    LLM   : Siapakah nama lengkapmu?
#    Waktu Proses: 0.16s
#
# 148. ✓ Kata Benar: 1.00
#    Input : Di manakah temapt kelahiranmu?
#    Target: Di manakah tempat kelahiranmu?
#    LLM   : Di manakah tempat kelahiranmu?
#    Waktu Proses: 0.19s
#
# 149. ✗ Kata Benar: 0.67
#    Input : Kapankah tanggal kelhiraanmu?
#    Target: Kapankah tanggal kelahiranmu?
#    LLM   : Kapankah tanggal lahirmu?
#    Waktu Proses: 0.18s
#
# 150. ✗ Kata Benar: 0.67
#    Input : Siapakah nama ayamhu?
#    Target: Siapakah nama ayahmu?
#    LLM   : Siapakah nama ayamnya?
#    Waktu Proses: 0.16s
#
# 151. ✗ Kata Benar: 0.67
#    Input : Siapakah nama mibuu?
#    Target: Siapakah nama ibumu?
#    LLM   : Siapakah nama muibu?
#    Waktu Proses: 0.14s
#
# 152. ✗ Kata Benar: 0.83
#    Input : Tanggal berapakah akta kelhairan itu dibuat?
#    Target: Tanggal berapakah akta kelahiran itu dibuat?
#    LLM   : Tanggal berapakah akte kelahiran itu dibuat?
#    Waktu Proses: 0.22s
#
# 153. ✗ Kata Benar: 0.40
#    Input : Id manakah akta itu dibuat?
#    Target: Di manakah akta itu dibuat?
#    LLM   : Id manakah itu akta dibuat?
#    Waktu Proses: 0.17s
#
# 154. ✗ Kata Benar: 0.83
#    Input : Sekarang kita akan meumbat map dokumen.
#    Target: Sekarang kita akan membuat map dokumen.
#    LLM   : Sekarang kita akan membaca map dokumen.
#    Waktu Proses: 0.21s
#
# 155. ✗ Kata Benar: 0.88
#    Input : Tempelkanlah foto dirimu di bagian paling adepn map.
#    Target: Tempelkanlah foto dirimu di bagian paling depan map.
#    LLM   : Tempelkanlah foto dirimu di bagian paling atas map.
#    Waktu Proses: 0.25s
#
# 156. ✗ Kata Benar: 0.92
#    Input : Tempelkanlah foto-foto lainnya atau gambar-gambar lucu keskaanumu di bagian depan dan belakang map.
#    Target: Tempelkanlah foto-foto lainnya atau gambar-gambar lucu kesukaanmu di bagian depan dan belakang map.
#    LLM   : Tempelkanlah foto-foto lainnya atau gambar-gambar lucu kekesaanmu di bagian depan dan belakang map.
#    Waktu Proses: 0.49s
#
# 157. ✗ Kata Benar: 0.88
#    Input : Jangan lupa sisakan bagian untuk menuliskan nmamau sendiri.
#    Target: Jangan lupa sisakan bagian untuk menuliskan namamu sendiri.
#    LLM   : Jangan lupa sisakan bagian untuk menulis namamu sendiri.
#    Waktu Proses: 0.27s
#
# 158. ✗ Kata Benar: 0.88
#    Input : Jika mau, buatlah judul untuk map teresbut sesukamu.
#    Target: Jika mau, buatlah judul untuk map tersebut sesukamu.
#    LLM   : Jika mau, buatlah judul untuk makalah tersebut sesukamu.
#    Waktu Proses: 0.28s
#
# 159. ✗ Kata Benar: 0.22
#    Input : Simpanlah foto kopi akta kelahiranmu di map buatanmu rsendii.
#    Target: Simpanlah foto kopi akta kelahiranmu di map buatanmu sendiri.
#    LLM   : Simpanlah foto kopinya aktakelahiranmu di map buatannya sendiri.
#    Waktu Proses: 0.33s
#
# 160. ✓ Kata Benar: 1.00
#    Input : Guru meminta dan mendorong anak untuk meneritakacn peristiwa berkesan yang pernah dialami anak.
#    Target: Guru meminta dan mendorong anak untuk menceritakan peristiwa berkesan yang pernah dialami anak.
#    LLM   : Guru meminta dan mendorong anak untuk menceritakan peristiwa berkesan yang pernah dialami anak.
#    Waktu Proses: 0.42s
#
# 161. ✗ Kata Benar: 0.67
#    Input : Deni tidak bosan memperhatinka fotonya.
#    Target: Deni tidak bosan memperhatikan fotonya.
#    LLM   : Deni tidak bosan memperhatikan foto nya.
#    Waktu Proses: 0.22s
#
# 162. ✓ Kata Benar: 1.00
#    Input : Foto itu terpasang di dinding dalam nruag keluarga.
#    Target: Foto itu terpasang di dinding dalam ruang keluarga.
#    LLM   : Foto itu terpasang di dinding dalam ruang keluarga.
#    Waktu Proses: 0.27s
#
# 163. ✗ Kata Benar: 0.60
#    Input : Di foto itu ia sedang memegang lpiaa didampingi ibunya.
#    Target: Di foto itu ia sedang memegang piala didampingi ibunya.
#    LLM   : Di foto itu ia sedang memegang lipiaa di dampingi ibunya.
#    Waktu Proses: 0.31s
#
# 164. ✓ Kata Benar: 1.00
#    Input : Deni merasa sanagt bangga.
#    Target: Deni merasa sangat bangga.
#    LLM   : Deni merasa sangat bangga.
#    Waktu Proses: 0.18s
#
# 165. ✗ Kata Benar: 0.71
#    Input : Saat itu deni mengtikui lomba sempoa.
#    Target: Saat itu deni mengikuti lomba sempoa.
#    LLM   : Saat itu Deni mengikuti lomba sepak bola.
#    Waktu Proses: 0.25s
#
# 166. ✗ Kata Benar: 0.75
#    Input : Deni ditunjuk mewkaili sekolahnya.
#    Target: Deni ditunjuk mewakili sekolahnya.
#    LLM   : Deni ditunjuk mengkali sekolahnya.
#    Waktu Proses: 0.22s
#
# 167. ✗ Kata Benar: 0.25
#    Input : Dien sangat gugup dan takut kalah.
#    Target: Deni sangat gugup dan takut kalah.
#    LLM   : Dien sangat gugup dan takut kalah.
#
# (no correction needed, but for perfection)
#
# Dien sangat gugup dan takut ia akan kalah.
#    Waktu Proses: 0.55s
#
# 168. ✓ Kata Benar: 1.00
#    Input : Jantungnya berdetak sanagt keras.
#    Target: Jantungnya berdetak sangat keras.
#    LLM   : Jantungnya berdetak sangat keras.
#    Waktu Proses: 0.21s
#
# 169. ✗ Kata Benar: 0.50
#    Input : Tanpa disangka iden menang.
#    Target: Tanpa disangka deni menang.
#    LLM   : Tanpa disangka, ident menang.
#    Waktu Proses: 0.27s
#
# 170. ✓ Kata Benar: 1.00
#    Input : Deni senang seklai.
#    Target: Deni senang sekali.
#    LLM   : Deni senang sekali.
#    Waktu Proses: 0.14s
#
# 171. ✗ Kata Benar: 0.86
#    Input : Teman-teman dan guru berebutan untuk mengucapkan selmaat.
#    Target: Teman-teman dan guru berebutan untuk mengucapkan selamat.
#    LLM   : Teman-teman dan guru berebutan untuk mengucapkan salamat.
#    Waktu Proses: 0.28s
#
# 172. ✗ Kata Benar: 0.86
#    Input : Peristiwa itu tidak akan pernah ia lupkaan.
#    Target: Peristiwa itu tidak akan pernah ia lupakan.
#    LLM   : Peristiwa itu tidak akan pernah ia lupakaan.
#    Waktu Proses: 0.22s
#
# 173. ✗ Kata Benar: 0.44
#    Input : Kamu pun pasti memiliki peristiwa atau penalamgan yang berkesan.
#    Target: Kamu pun pasti memiliki peristiwa atau pengalaman yang berkesan.
#    LLM   : Kamu pun pasti memiliki pengalaman yang berkesan.
#    Waktu Proses: -0.65s
#
# 174. ✓ Kata Benar: 1.00
#    Input : Ceritakanlah di depan teman-temanmu peristiwa atau penalamgan berkesan yang pernah kamu alami itu.
#    Target: Ceritakanlah di depan teman-temanmu peristiwa atau pengalaman berkesan yang pernah kamu alami itu.
#    LLM   : Ceritakanlah di depan teman-temanmu peristiwa atau pengalaman berkesan yang pernah kamu alami itu.
#    Waktu Proses: -0.86s
#
# 175. ✗ Kata Benar: 0.36
#    Input : Lewat foto itu pasya mengenang lagi amsa lalunya, ketika ia sedang dikhitan.
#    Target: Lewat foto itu pasya mengenang lagi masa lalunya, ketika ia sedang dikhitan.
#    LLM   : Lewat foto itu, pasya mengenang lagi masa laluinya, ketika ia sedang dikhitan menjadi "dihitung" salah satu transposisi, tapi lebih masuk akal adalah masa (masa lalu).
#    Waktu Proses: 0.72s
#
# 176. ✗ Kata Benar: 0.20
#    Input : Ternyata dikhitan atidk sakit.
#    Target: Ternyata dikhitan tidak sakit.
#    LLM   : Ternyata diukhti an tidak sakit.
#    Waktu Proses: 0.20s
#
# 177. ✓ Kata Benar: 1.00
#    Input : Peristiwa khitanan bagi anak laki-laki merupakan persitiwa besar.
#    Target: Peristiwa khitanan bagi anak laki-laki merupakan peristiwa besar.
#    LLM   : Peristiwa khitanan bagi anak laki-laki merupakan peristiwa besar.
#    Waktu Proses: 0.28s
#
# 178. ✗ Kata Benar: 0.60
#    Input : Lomba apakah yang diuikti deni?
#    Target: Lomba apakah yang diikuti deni?
#    LLM   : Lomba apa yang diuji deni?
#    Waktu Proses: 0.16s
#
# 179. ✗ Kata Benar: 0.21
#    Input : Apa yang terjadi setelah deni ditunjuk mewkaili sekolahnya?
#    Target: Apa yang terjadi setelah deni ditunjuk mewakili sekolahnya?
#    LLM   : Apa yang terjadi setelah Deni ditunjuk mengwajili sekolahnya?
#
#  Corrected:
# - Apa yang terjadi setelah Deni ditunjuk mengwajili -> ditunjuk menjabat
# - sekolahnya -> sekolah
#
# Corrected sentence:
#  Apa yang terjadi setelah deni ditunjuk menjabati sekolahnya?
#    Waktu Proses: 1.16s
#
# 180. ✓ Kata Benar: 1.00
#    Input : Bagaimanakah perasaan deni etkika melihat fotonya?
#    Target: Bagaimanakah perasaan deni ketika melihat fotonya?
#    LLM   : Bagaimanakah perasaan Deni ketika melihat fotonya?
#    Waktu Proses: 0.27s
#
# 181. ✗ Kata Benar: 0.86
#    Input : Foto apakah ayng diperlihatkan pasya kepada arman?
#    Target: Foto apakah yang diperlihatkan pasya kepada arman?
#    LLM   : Foto apakah yang diperlihatkan pasyaa kepada arman?
#    Waktu Proses: 0.27s
#
# 182. ✗ Kata Benar: 0.60
#    Input : Apakah pasya menangis etkika dikhitan?
#    Target: Apakah pasya menangis ketika dikhitan?
#    LLM   : Apakah paskah menangis ketika dikhitangi?
#    Waktu Proses: 0.24s
#
# 183. ✓ Kata Benar: 1.00
#    Input : Foto termasuk dokmuen diri.
#    Target: Foto termasuk dokumen diri.
#    LLM   : Foto termasuk dokumen diri.
#    Waktu Proses: 0.16s
#
# 184. ✗ Kata Benar: 0.62
#    Input : Foto berguna untuk mengenang peristiwa dimasa ulal.
#    Target: Foto berguna untuk mengenang peristiwa dimasa lalu.
#    LLM   : Foto berguna untuk mengenang peristiwa di masa lalu.
#    Waktu Proses: 0.25s
#
# 185. ✓ Kata Benar: 1.00
#    Input : Akta kelahiran, kartu keluarga, ktp, ijazah, dan sim hadala dokumen penting.
#    Target: Akta kelahiran, kartu keluarga, ktp, ijazah, dan sim adalah dokumen penting.
#    LLM   : Akta kelahiran, kartu keluarga, KTP, ijazah, dan SIM adalah dokumen penting.
#    Waktu Proses: 0.40s
#
# 186. ✗ Kata Benar: 0.55
#    Input : Akta kelahiran disebut juga sebagai surat dtana kenal lahir seseorang.
#    Target: Akta kelahiran disebut juga sebagai surat tanda kenal lahir seseorang.
#    LLM   : Akta kelahiran disebut juga sebagai surat lahir dan akta kenal seseorang.
#    Waktu Proses: 0.36s
#
# 187. ✓ Kata Benar: 1.00
#    Input : Dokumen penting harus dijaga dan dirawat denagn baik.
#    Target: Dokumen penting harus dijaga dan dirawat dengan baik.
#    LLM   : Dokumen penting harus dijaga dan dirawat dengan baik.
#    Waktu Proses: 0.26s
#
# 188. ✓ Kata Benar: 1.00
#    Input : Apa sajakah yang termasuk dokumen penting kelaurga?
#    Target: Apa sajakah yang termasuk dokumen penting keluarga?
#    LLM   : Apa sajakah yang termasuk dokumen penting keluarga?
#    Waktu Proses: 0.28s
#
# 189. ✓ Kata Benar: 1.00
#    Input : Apakah alat yang digunakan untuk mengambil ofto?
#    Target: Apakah alat yang digunakan untuk mengambil foto?
#    LLM   : Apakah alat yang digunakan untuk mengambil foto?
#    Waktu Proses: 0.22s
#
# 190. ✓ Kata Benar: 1.00
#    Input : Sebutnka guna akta kelahiran?
#    Target: Sebutkan guna akta kelahiran?
#    LLM   : Sebutkan guna akta kelahiran?
#    Waktu Proses: 0.20s
#
# 191. ✗ Kata Benar: 0.62
#    Input : Pmengaa dokumen penting keluarga harus dijaga dan dirawat?
#    Target: Mengapa dokumen penting keluarga harus dijaga dan dirawat?
#    LLM   : Pentingnya mengapa dokumen keluarga harus dijaga dan dirawat?
#    Waktu Proses: 0.30s
#
# 192. ✓ Kata Benar: 1.00
#    Input : Dokumen apakah yang harus dimiliki pengendara omtor dan mobil?
#    Target: Dokumen apakah yang harus dimiliki pengendara motor dan mobil?
#    LLM   : Dokumen apakah yang harus dimiliki pengendara motor dan mobil?
#    Waktu Proses: 0.27s
#
# 193. ✗ Kata Benar: 0.00
#    Input : Tiap keluarga punya periwstia penting.
#    Target: Tiap keluarga punya peristiwa penting.
#    LLM   : Periwstia penting tiap keluarga punya.
#    Waktu Proses: 0.24s
#
# 194. ✗ Kata Benar: 0.67
#    Input : Ada yang menenangkayn.
#    Target: Ada yang menyenangkan.
#    LLM   : Ada yang menenangkan.
#    Waktu Proses: 0.13s
#
# 195. ✗ Kata Benar: 0.67
#    Input : Ada yang menedihykan.
#    Target: Ada yang menyedihkan.
#    LLM   : Ada yang mendehyikan.
#    Waktu Proses: 0.15s
#
# 196. ✗ Kata Benar: 0.67
#    Input : Semuanya sangat berugna.
#    Target: Semuanya sangat berguna.
#    LLM   : Semuanya sangat buruk.
#    Waktu Proses: 0.15s
#
# 197. ✗ Kata Benar: 0.75
#    Input : Kita bisa iambl hikmahnya.
#    Target: Kita bisa ambil hikmahnya.
#    LLM   : Kita bisa amabil hikmahnya.
#    Waktu Proses: 0.17s
#
# 198. ✗ Kata Benar: 0.86
#    Input : Guru membimbing anak untuk mengetahui arti persitiwa.
# ...
#    LLM   : Peristiwa di masa lalu memiliki pengaruh terhadap peristiwa masa kini.
#    Waktu Proses: 0.34s
#
# 436. ✓ Kata Benar: 1.00
#    Input : Perilaku itu ada yang arhus ditingkatkan, ada yang harus diperbaiki, dan ada yang harus ditinggalkan.
#    Target: Perilaku itu ada yang harus ditingkatkan, ada yang harus diperbaiki, dan ada yang harus ditinggalkan.
#    LLM   : Perilaku itu ada yang harus ditingkatkan, ada yang harus diperbaiki, dan ada yang harus ditinggalkan.
#    Waktu Proses: 0.46s
#
# 437. ✗ Kata Benar: 0.00
#    Input : Seperti apakah contoh periwstia menyenangkan?
#    Target: Seperti apakah contoh peristiwa menyenangkan?
#    LLM   : Periwstia -> Peristiwa
# Contoh periwstia -> Contoh peristiwa
#
# Result:
# Seperti apakah contoh peristiwa menyenangkan?
#    Waktu Proses: 0.58s
#
# 438. ✓ Kata Benar: 1.00
#    Input : Seperti apakah contoh periwstia menyedihkan itu?
#    Target: Seperti apakah contoh peristiwa menyedihkan itu?
#    LLM   : Seperti apakah contoh peristiwa menyedihkan itu?
#    Waktu Proses: 0.25s
#
# 439. ✓ Kata Benar: 1.00
#    Input : Sebutkan perilaku yang hasru ditingkatkan?
#    Target: Sebutkan perilaku yang harus ditingkatkan?
#    LLM   : Sebutkan perilaku yang harus ditingkatkan?
#    Waktu Proses: 0.22s
#
# 440. ✗ Kata Benar: 0.60
#    Input : Apakah kamu pernah masla belajar?
#    Target: Apakah kamu pernah malas belajar?
#    LLM   : Apakah kamu pernah belajar malsa?
#    Waktu Proses: 0.19s
#
# 441. ✗ Kata Benar: 0.83
#    Input : Paa yang kamu lakukan untuk memperbaikinya?
#    Target: Apa yang kamu lakukan untuk memperbaikinya?
#    LLM   : Pada yang kamu lakukan untuk memperbaikinya?
#    Waktu Proses: 0.23s
#
# 442. ✗ Kata Benar: 0.80
#    Input : Tiap organ punya orang tua.
#    Target: Tiap orang punya orang tua.
#    LLM   : Tiap orang punya organ tua.
#    Waktu Proses: 0.16s
#
# 443. ✗ Kata Benar: 0.40
#    Input : Karena itu, dapat diabut silsilah.
#    Target: Karena itu, dapat dibuat silsilah.
#    LLM   : Karena itu, silsilah dapat dibuat.
#    Waktu Proses: 0.20s
#
# 444. ✗ Kata Benar: 0.80
#    Input : Kamu harus tahu slsilaih keluargamu.
#    Target: Kamu harus tahu silsilah keluargamu.
#    LLM   : Kamu harus tahu silsilaih keluargamu.
#    Waktu Proses: 0.24s
#
# 445. ✗ Kata Benar: 0.50
#    Input : Kamu harus tahu keduadukn anak.
#    Target: Kamu harus tahu kedudukan anak.
#    LLM   : Kamu harus tahu kedua dukun anak.
#    Waktu Proses: -0.75s
#
# 446. ✗ Kata Benar: 0.83
#    Input : Kamu harus tahu keduadukn orang tua.
#    Target: Kamu harus tahu kedudukan orang tua.
#    LLM   : Kamu harus tahu kedua orang tua.
#    Waktu Proses: 0.19s
#
# 447. ✓ Kata Benar: 1.00
#    Input : Kamu juga harus tahu peran anggota kelaurga.
#    Target: Kamu juga harus tahu peran anggota keluarga.
#    LLM   : Kamu juga harus tahu peran anggota keluarga.
#    Waktu Proses: -1.12s
#
# 448. ✗ Kata Benar: 0.92
#    Input : Guru membimbing anak untuk mengetahui arti ilsislah keluarga dan dapat menceritakan silsilah keluarganya.
#    Target: Guru membimbing anak untuk mengetahui arti silsilah keluarga dan dapat menceritakan silsilah keluarganya.
#    LLM   : Guru membimbing anak untuk mengetahui arti isilah keluarga dan dapat menceritakan silsilah keluarganya.
#    Waktu Proses: 0.51s
#
# 449. ✗ Kata Benar: 0.80
#    Input : Silsilah keluarga dimiliki seatip keluarga.
#    Target: Silsilah keluarga dimiliki setiap keluarga.
#    LLM   : Silsilah keluarga dimiliki tiap keluarga.
#    Waktu Proses: 0.26s
#
# 450. ✗ Kata Benar: 0.80
#    Input : Silsilah keluarga artinya asalu-sul keluarga.
#    Target: Silsilah keluarga artinya asal-usul keluarga.
#    LLM   : Silsilah keluarga artinya suku-suku keluarga.
#    Waktu Proses: 0.29s
#
# 451. ✗ Kata Benar: 0.83
#    Input : Keluargamu tentu juga memiikli silsilah keluarga.
#    Target: Keluargamu tentu juga memiliki silsilah keluarga.
#    LLM   : Keluargamu tentu juga memilih silsilah keluarga.
#    Waktu Proses: 0.27s
#
# 452. ✗ Kata Benar: 0.42
#    Input : Aki rahmat dan nini ratna adalah norag tua ayahku.
#    Target: Aki rahmat dan nini ratna adalah orang tua ayahku.
#    LLM   : Aki rahmat dan Nini Ratna adalah narag tua ayahku.
#
# Corrected sentence:
# Nini Ratna dan Aki Rahmat adalah ayahanda saya.
#    Waktu Proses: 0.58s
#
# 453. ✓ Kata Benar: 1.00
#    Input : Ayahku adalah orang sunda, jadi kakek dan nenekku dipanglgi aki dan nini.
#    Target: Ayahku adalah orang sunda, jadi kakek dan nenekku dipanggil aki dan nini.
#    LLM   : Ayahku adalah orang Sunda, jadi kakek dan nenekku dipanggil aki dan nini.
#    Waktu Proses: 0.41s
#
# 454. ✗ Kata Benar: 0.91
#    Input : Eyang kakung argo dan eyang putri mlasi adalah orang tua ibuku.
#    Target: Eyang kakung argo dan eyang putri lasmi adalah orang tua ibuku.
#    LLM   : Eyang Kakung Argo dan Eyang Putri Mauliati adalah orang tua ibuku.
#    Waktu Proses: 0.33s
#
# 455. ✓ Kata Benar: 1.00
#    Input : Ibuku adalah norag jawa.
#    Target: Ibuku adalah orang jawa.
#    LLM   : Ibuku adalah orang Jawa.
#    Waktu Proses: 0.16s
#
# 456. ✗ Kata Benar: 0.91
#    Input : Kakek disebut dengan eyang kakung dan ennek disebut dengan eyang putri.
#    Target: Kakek disebut dengan eyang kakung dan nenek disebut dengan eyang putri.
#    LLM   : Kakek disebut dengan eyang kakung dan ende disebut dengan eyang putri.
#    Waktu Proses: 0.35s
#
# 457. ✗ Kata Benar: 0.88
#    Input : Jiad aku memiliki dua kakek dan dua nenek.
#    Target: Jadi aku memiliki dua kakek dan dua nenek.
#    LLM   : Jika aku memiliki dua kakek dan dua nenek.
#    Waktu Proses: 0.23s
#
# 458. ✗ Kata Benar: 0.90
#    Input : Ayah adalah anak bungsu dan memiliki usat kakak, namanya sarah.
#    Target: Ayah adalah anak bungsu dan memiliki satu kakak, namanya sarah.
#    LLM   : Ayah adalah anak bungsu dan memiliki saudara kakak, namanya Sarah.
#    Waktu Proses: 0.31s
#
# 459. ✗ Kata Benar: 0.75
#    Input : Aku memanggilnya kuwa sarah.
#    Target: Aku memanggilnya uwak sarah.
#    LLM   : Aku memanggilnya adalah Sarah.
#    Waktu Proses: 0.17s
#
# 460. ✗ Kata Benar: 0.83
#    Input : Uwak sarah menikah deangn uwak tanto.
#    Target: Uwak sarah menikah dengan uwak tanto.
#    LLM   : Uwak Saran menikah dengan uwak Tanto.
#    Waktu Proses: 0.25s
#
# 461. ✗ Kata Benar: 0.00
#    Input : Amerek memiliki dua anak, yaitu nindi dan hari.
#    Target: Mereka memiliki dua anak, yaitu nindi dan hari.
#    LLM   : - User: Amerek memiliki dua anak, yaitu nindi dan hari.
# - Assistant: Amerika memiliki dua anak, yaitu India dan Hari.
#    Waktu Proses: 0.49s
#
# 462. ✗ Kata Benar: 0.67
#    Input : Mereka adalah seppuuku.
#    Target: Mereka adalah sepupuku.
#    LLM   : Mereka adalah sepupu.
#    Waktu Proses: 0.16s
#
# 463. ✗ Kata Benar: 0.44
#    Input : Ibuku memiliki saudara kembar, namanya tante arin.
#    Target: Ibuku memiliki saudara kembar, namanya tante rina.
#    LLM   : Ibuku memiliki saudara kembar, nama nya adalah Tante Arin.
#    Waktu Proses: 0.30s
#
# 464. ✗ Kata Benar: 0.86
#    Input : Wajah ibu dan tante rina sangat imrip.
#    Target: Wajah ibu dan tante rina sangat mirip.
#    LLM   : Wajah ibu dan tante Rina sangat iri.
#    Waktu Proses: 0.24s
#
# 465. ✗ Kata Benar: 0.91
#    Input : Tante rina menikah dengan om wandi itap mereka belum punya anak.
#    Target: Tante rina menikah dengan om wandi tapi mereka belum punya anak.
#    LLM   : Tante Rina menikah dengan Om Wandi itu, mereka belum punya anak.
#    Waktu Proses: 0.32s
#
# 466. ✗ Kata Benar: 0.83
#    Input : Seperti ibuku, aku ugja anak kembar.
#    Target: Seperti ibuku, aku juga anak kembar.
#    LLM   : Seperti ibuku, aku adalah anak kembar.
#    Waktu Proses: 0.20s
#
# 467. ✗ Kata Benar: 0.20
#    Input : Saudara kembarku nmanaya irna.
#    Target: Saudara kembarku namanya irna.
#    LLM   : Saudara kembar-ku, mana ya irina?
#    Waktu Proses: 0.23s
#
# 468. ✗ Kata Benar: 0.00
#    Input : Namaku adalah airm.
#    Target: Namaku adalah irma.
#    LLM   : Nama ku adalah Aria.
#    Waktu Proses: 0.13s
#
# 469. ✗ Kata Benar: 0.80
#    Input : Orang sering bingung menglenai kami.
#    Target: Orang sering bingung mengenali kami.
#    LLM   : Orang sering bingung mengenal kami.
#    Waktu Proses: 0.21s
#
# 470. ✗ Kata Benar: 0.57
#    Input : Aku juga punya diak, namanya tomi.
#    Target: Aku juga punya adik, namanya tomi.
#    LLM   : Aku juga punya adik, nama saya Tomi.
#    Waktu Proses: 0.28s
#
# 471. ✗ Kata Benar: 0.67
#    Input : Tomi masih baltia.
#    Target: Tomi masih balita.
#    LLM   : Tomi masih Bali.
#    Waktu Proses: 0.12s
#
# 472. ✓ Kata Benar: 1.00
#    Input : Apa artinya silsilah kelurgaa itu?
#    Target: Apa artinya silsilah keluarga itu?
#    LLM   : Apa artinya silsilah keluarga itu?
#    Waktu Proses: 0.24s
#
# 473. ✗ Kata Benar: 0.83
#    Input : Silsilah keluarga siapakah anyg diceritakan tadi?
#    Target: Silsilah keluarga siapakah yang diceritakan tadi?
#    LLM   : Silislah keluarga siapakah yang diceritakan tadi?
#    Waktu Proses: 0.31s
#
# 474. ✗ Kata Benar: 0.50
#    Input : Sebutkan nama ekakk irma?
#    Target: Sebutkan nama kakek irma?
#    LLM   : Sebutkan nama ikarima.
#    Waktu Proses: 0.16s
#
# 475. ✗ Kata Benar: 0.00
#    Input : Siapahka orang tua nindi?
#    Target: Siapakah orang tua nindi?
#    LLM   : Siapa haka orang tua itu?
#    Waktu Proses: 0.16s
#
# 476. ✓ Kata Benar: 1.00
#    Input : Siapakah saudara kembar ibu dan siapakah suaimnya?
#    Target: Siapakah saudara kembar ibu dan siapakah suaminya?
#    LLM   : Siapakah saudara kembar ibu dan siapakah suaminya?
#    Waktu Proses: 0.30s
#
# 477. ✗ Kata Benar: 0.50
#    Input : Buatlah silsilah keluargamu seindri seperti contoh.
#    Target: Buatlah silsilah keluargamu sendiri seperti contoh.
#    LLM   : Buatlah silsilah keluargamu seperti contoh seindari.
#    Waktu Proses: 0.29s
#
# 478. ✗ Kata Benar: 0.75
#    Input : Tanyakan pada norag tuamu.
#    Target: Tanyakan pada orang tuamu.
#    LLM   : Tanyakan pada nagor tuamu.
#    Waktu Proses: 0.17s
#
# 479. ✗ Kata Benar: 0.67
#    Input : Ceritakanlah kepada teman-temanmu di kelas tentang ilsislah keluargamu.
#    Target: Ceritakanlah kepada teman-temanmu di kelas tentang silsilah keluargamu.
#    LLM   : Ceritakanlah kepada teman-temanmu di kelas tentang ilmu sihlah keluargamu.
#    Waktu Proses: 0.42s
#
# 480. ✓ Kata Benar: 1.00
#    Input : Secara umum guru menerangkan kedudukan serta apern semua anggota keluarga.
#    Target: Secara umum guru menerangkan kedudukan serta peran semua anggota keluarga.
#    LLM   : Secara umum guru menerangkan kedudukan serta peran semua anggota keluarga.
#    Waktu Proses: 0.34s
#
# 481. ✓ Kata Benar: 1.00
#    Input : Lebih baik jika guru menjelaskan dengan memebri contoh menggunakan alat peraga, misalnya foto satu keluarga (tergantung kreativitas guru).
#    Target: Lebih baik jika guru menjelaskan dengan memberi contoh menggunakan alat peraga, misalnya foto satu keluarga (tergantung kreativitas guru).
#    LLM   : Lebih baik jika guru menjelaskan dengan memberi contoh menggunakan alat peraga, misalnya foto satu keluarga (tergantung kreativitas guru).
#    Waktu Proses: 0.59s
#
# 482. ✗ Kata Benar: 0.41
#    Input : Bimbinglah anak supaya mengetahui peran dan keddukannyua sendiri dalam keluarga.
#    Target: Bimbinglah anak supaya mengetahui peran dan kedudukannya sendiri dalam keluarga.
#    LLM   : Bimbinglah anak supaya mengetahui peran dan kepadudukannya sendiri dalam keluarga.
#
# Corrected sentence:
#  Bimbinglah anak supaya mengetahui peran dan kedudukan sendiri dalam keluarga.
#    Waktu Proses: 0.81s
#
# 483. ✓ Kata Benar: 1.00
#    Input : Setiap orang mempunyai keluarga, seperti juga ukam.
#    Target: Setiap orang mempunyai keluarga, seperti juga kamu.
#    LLM   : Setiap orang mempunyai keluarga, seperti juga kamu.
#    Waktu Proses: 0.26s
#
# 484. ✗ Kata Benar: 0.18
#    Input : Di dalam keluarga biasanya terdiri dari bbereapa orang, misalnya ada ayah, ibu, nenek, kakek, kakak, adik, dan lain-lain.
#    Target: Di dalam keluarga biasanya terdiri dari beberapa orang, misalnya ada ayah, ibu, nenek, kakek, kakak, adik, dan lain-lain.
#    LLM   : Di dalam keluarga biasanya terdiri dari berapa banyak orang, misalnya ada ayah, ibu, nenek, kakek, kakak, adik, dan lain-lain.
#
# (Korrek: "berapa" dan "banyak" adalah kata yang sangat mirip dan sering digunakan secara tidak tepat)
#    Waktu Proses: 1.07s
#
# 485. ✓ Kata Benar: 1.00
#    Input : Coba sebutkan ada siapa saja di rumhamu?
#    Target: Coba sebutkan ada siapa saja di rumahmu?
#    LLM   : Coba sebutkan ada siapa saja di rumahmu?
#    Waktu Proses: 0.24s
#
# 486. ✓ Kata Benar: 1.00
#    Input : Semua anggota keluarga mempaunyi kedudukan.
#    Target: Semua anggota keluarga mempunyai kedudukan.
#    LLM   : Semua anggota keluarga mempunyai kedudukan.
#    Waktu Proses: 0.26s
#
# 487. ✓ Kata Benar: 1.00
#    Input : Kedudukan setiap anggota kelurgaa berbeda.
#    Target: Kedudukan setiap anggota keluarga berbeda.
#    LLM   : Kedudukan setiap anggota keluarga berbeda.
#    Waktu Proses: 0.26s
#
# 488. ✗ Kata Benar: 0.25
#    Input : Ini adalah kelaurga andrea.
#    Target: Ini adalah keluarga andrea.
#    LLM   : Kelaurga ini adalah Andrea.
#    Waktu Proses: 0.14s
#
# 489. ✓ Kata Benar: 1.00
#    Input : Jumlah anggota keluarga andrea ada lima norag.
#    Target: Jumlah anggota keluarga andrea ada lima orang.
#    LLM   : Jumlah anggota keluarga Andrea ada lima orang.
#    Waktu Proses: 0.23s
#
# 490. ✓ Kata Benar: 1.00
#    Input : Yaitu ayah, ibu, kakak, andrea, dan kadi.
#    Target: Yaitu ayah, ibu, kakak, andrea, dan adik.
#    LLM   : Yaitu ayah, ibu, kakak, Andrea, dan adik.
#    Waktu Proses: 0.30s
#
# 491. ✗ Kata Benar: 0.86
#    Input : Andrea adalah anak kedua dari tiga beraudasra.
#    Target: Andrea adalah anak kedua dari tiga bersaudara.
#    LLM   : Andrea adalah anak kedua dari tiga beradatrasa.
#    Waktu Proses: 0.26s
#
# 492. ✗ Kata Benar: 0.20
#    Input : Kakak andrea nmanaya pasya.
#    Target: Kakak andrea namanya pasya.
#    LLM   : Kakak Andrea, mana ya pasnya?
#    Waktu Proses: 0.19s
#
# 493. ✗ Kata Benar: 0.50
#    Input : Pasya adalah kana pertama.
#    Target: Pasya adalah anak pertama.
#    LLM   : Pasa adalah kana pertama.
#    Waktu Proses: 0.16s
#
# 494. ✗ Kata Benar: 0.75
#    Input : Dimi adalah kadi andrea.
#    Target: Dimi adalah adik andrea.
#    LLM   : Dimi adalah kadi Andrea.
#    Waktu Proses: 0.14s
#
# 495. ✗ Kata Benar: 0.60
#    Input : Ahya andrea namanya pak aswan.
#    Target: Ayah andrea namanya pak aswan.
#    LLM   : Andi Ahya namanya Pak Aswan.
#    Waktu Proses: 0.20s
#
# 496. ✗ Kata Benar: 0.75
#    Input : Apk aswan adalah kepala keluarga, suami, dan ayah.
#    Target: Pak aswan adalah kepala keluarga, suami, dan ayah.
#    LLM   : Apakah aswannya adalah kepala keluarga, suami, dan ayah.
#    Waktu Proses: 0.32s
#
# 497. ✗ Kata Benar: 0.75
#    Input : Ibunda andrea beranma intan.
#    Target: Ibunda andrea bernama intan.
#    LLM   : Ibunda Andrea bermain intan.
#    Waktu Proses: 0.17s
#
# 498. ✓ Kata Benar: 1.00
#    Input : Sehari-hari dipanggil bu aswan karena ibu adaalh istri pak aswan.
#    Target: Sehari-hari dipanggil bu aswan karena ibu adalah istri pak aswan.
#    LLM   : Sehari-hari dipanggil Bu Aswan karena Ibu adalah istri Pak Aswan.
#    Waktu Proses: 0.33s
#
# 499. ✓ Kata Benar: 1.00
#    Input : Guru menerangkan tentang kedudukan orang tua adlam keluarga.
#    Target: Guru menerangkan tentang kedudukan orang tua dalam keluarga.
#    LLM   : Guru menerangkan tentang kedudukan orang tua dalam keluarga.
#    Waktu Proses: 0.27s
#
# 500. ✗ Kata Benar: 0.86
#    Input : Munculkan rasa hormat anak terhadap orang tuayna.
#    Target: Munculkan rasa hormat anak terhadap orang tuanya.
#    LLM   : Munculkan rasa hormat anak terhadap orang tua-nya.
#    Waktu Proses: 0.27s
#
#
# Hasil detail telah disimpan ke file: IPS_output_transposition_error.csv_hasil_koreksi_ejaan.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 45
#      41 print(f"\nHasil detail telah disimpan ke file: {output_filename}")
#      43 # Simpan juga ringkasan hasil
#      44 summary_data = {
# ---> 45     'Model': [model_name],
#      46     'Exact_Match_Accuracy': [exact_acc],
#      47     'Word_Match_Accuracy': [kata_acc],
#      48     'Avg_Processing_Time': [np.mean(processing_times)]
#      49 }
#      50 df_summary = pd.DataFrame(summary_data)
#      51 summary_filename = f"{uploaded_filename}_ringkasan_akurasi.csv"
#
# NameError: name 'model_name' is not defined

# %%
# Visualisasi distribusi akurasi kata berdasarkan kelompok
plt.figure(figsize=(12, 7))

# Definisikan kategori akurasi
categories = ["100%", "99% - 70%", "69% - 40%", "39% - 0%"]
category_ranges = [(1.0, 1.0), (0.7, 0.99), (0.4, 0.69), (0.0, 0.39)]
colors = ['#2ecc71', '#27ae60', '#f39c12', '#e74c3c']  # Warna berbeda untuk tiap kategori

# Hitung jumlah kalimat per kategori
counts = []
for lower, upper in category_ranges:
    count = sum(1 for acc in kata_detail if lower <= acc <= upper)
    counts.append(count)

# Buat bar chart
bars = plt.bar(categories, counts, color=colors)
plt.xlabel('Kategori Akurasi')
plt.ylabel('Jumlah Kalimat')
plt.title('Distribusi Akurasi Koreksi Ejaan')

# Tambahkan label jumlah dan persentase pada setiap bar
total = sum(counts)
for bar in bars:
    height = bar.get_height()
    percentage = (height / total) * 100 if total > 0 else 0
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.1,
             f"{int(height)} ({percentage:.1f}%)", ha='center', va='bottom')

# Tampilkan total kalimat di judul
plt.title(f'Distribusi Akurasi Koreksi Ejaan (Total: {total} kalimat)')

plt.ylim(0, max(counts) + max(counts)*0.2 if counts else 1)  # Memberi ruang untuk label
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

# Save the figure before showing it
filename = f"{uploaded_filename}_distribution_accuracy.png"
plt.savefig(filename, bbox_inches='tight', dpi=300)
plt.show()
